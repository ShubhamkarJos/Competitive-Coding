# %%
pip install iNLTK
# Out:
# Requirement already satisfied: iNLTK in /usr/local/lib/python3.6/dist-packages (0.9)
# Requirement already satisfied: pandas in /usr/local/lib/python3.6/dist-packages (from iNLTK) (1.1.4)
# Requirement already satisfied: numpy>=1.15 in /usr/local/lib/python3.6/dist-packages (from iNLTK) (1.18.5)
# Requirement already satisfied: fastai==1.0.57 in /usr/local/lib/python3.6/dist-packages (from iNLTK) (1.0.57)
# Requirement already satisfied: packaging in /usr/local/lib/python3.6/dist-packages (from iNLTK) (20.4)
# Requirement already satisfied: aiohttp>=3.5.4 in /usr/local/lib/python3.6/dist-packages (from iNLTK) (3.7.3)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.6/dist-packages (from iNLTK) (0.1.94)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.6/dist-packages (from iNLTK) (7.0.0)
# Requirement already satisfied: spacy>=2.0.18 in /usr/local/lib/python3.6/dist-packages (from iNLTK) (2.2.4)
# Requirement already satisfied: numexpr in /usr/local/lib/python3.6/dist-packages (from iNLTK) (2.7.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.6/dist-packages (from iNLTK) (1.4.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.6/dist-packages (from iNLTK) (3.2.2)
# Requirement already satisfied: bottleneck in /usr/local/lib/python3.6/dist-packages (from iNLTK) (1.3.2)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.6/dist-packages (from iNLTK) (4.6.3)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.6/dist-packages (from iNLTK) (3.13)
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from iNLTK) (2.23.0)
# Requirement already satisfied: typing in /usr/local/lib/python3.6/dist-packages (from iNLTK) (3.7.4.3)
# Requirement already satisfied: dataclasses; python_version < "3.7" in /usr/local/lib/python3.6/dist-packages (from iNLTK) (0.8)
# Requirement already satisfied: nvidia-ml-py3 in /usr/local/lib/python3.6/dist-packages (from iNLTK) (7.352.0)
# Requirement already satisfied: async-timeout>=3.0.1 in /usr/local/lib/python3.6/dist-packages (from iNLTK) (3.0.1)
# Requirement already satisfied: fastprogress>=0.1.19 in /usr/local/lib/python3.6/dist-packages (from iNLTK) (1.0.0)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.6/dist-packages (from pandas->iNLTK) (2018.9)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.6/dist-packages (from pandas->iNLTK) (2.8.1)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.6/dist-packages (from fastai==1.0.57->iNLTK) (0.8.1+cu101)
# Requirement already satisfied: torch>=1.0.0 in /usr/local/lib/python3.6/dist-packages (from fastai==1.0.57->iNLTK) (1.7.0+cu101)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.6/dist-packages (from packaging->iNLTK) (2.4.7)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from packaging->iNLTK) (1.15.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.6/dist-packages (from aiohttp>=3.5.4->iNLTK) (20.3.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.6/dist-packages (from aiohttp>=3.5.4->iNLTK) (5.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.6/dist-packages (from aiohttp>=3.5.4->iNLTK) (1.6.3)
# Requirement already satisfied: idna-ssl>=1.0; python_version < "3.7" in /usr/local/lib/python3.6/dist-packages (from aiohttp>=3.5.4->iNLTK) (1.1.0)
# Requirement already satisfied: chardet<4.0,>=2.0 in /usr/local/lib/python3.6/dist-packages (from aiohttp>=3.5.4->iNLTK) (3.0.4)
# Requirement already satisfied: typing-extensions>=3.6.5 in /usr/local/lib/python3.6/dist-packages (from aiohttp>=3.5.4->iNLTK) (3.7.4.3)
# Requirement already satisfied: srsly<1.1.0,>=1.0.2 in /usr/local/lib/python3.6/dist-packages (from spacy>=2.0.18->iNLTK) (1.0.4)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.6/dist-packages (from spacy>=2.0.18->iNLTK) (4.41.1)
# Requirement already satisfied: catalogue<1.1.0,>=0.0.7 in /usr/local/lib/python3.6/dist-packages (from spacy>=2.0.18->iNLTK) (1.0.0)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from spacy>=2.0.18->iNLTK) (3.0.4)
# Requirement already satisfied: wasabi<1.1.0,>=0.4.0 in /usr/local/lib/python3.6/dist-packages (from spacy>=2.0.18->iNLTK) (0.8.0)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.6/dist-packages (from spacy>=2.0.18->iNLTK) (2.0.4)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.6/dist-packages (from spacy>=2.0.18->iNLTK) (1.0.4)
# Requirement already satisfied: thinc==7.4.0 in /usr/local/lib/python3.6/dist-packages (from spacy>=2.0.18->iNLTK) (7.4.0)
# Requirement already satisfied: plac<1.2.0,>=0.9.6 in /usr/local/lib/python3.6/dist-packages (from spacy>=2.0.18->iNLTK) (1.1.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from spacy>=2.0.18->iNLTK) (50.3.2)
# Requirement already satisfied: blis<0.5.0,>=0.4.0 in /usr/local/lib/python3.6/dist-packages (from spacy>=2.0.18->iNLTK) (0.4.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.6/dist-packages (from matplotlib->iNLTK) (0.10.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.6/dist-packages (from matplotlib->iNLTK) (1.3.1)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->iNLTK) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->iNLTK) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->iNLTK) (2020.11.8)
# Requirement already satisfied: future in /usr/local/lib/python3.6/dist-packages (from torch>=1.0.0->fastai==1.0.57->iNLTK) (0.16.0)
# Requirement already satisfied: importlib-metadata>=0.20; python_version < "3.8" in /usr/local/lib/python3.6/dist-packages (from catalogue<1.1.0,>=0.0.7->spacy>=2.0.18->iNLTK) (2.0.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.6/dist-packages (from importlib-metadata>=0.20; python_version < "3.8"->catalogue<1.1.0,>=0.0.7->spacy>=2.0.18->iNLTK) (3.4.0)

# %%
from inltk.inltk import setup
setup('hi')
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-3-b44c9c2498dd> in <module>()
#       1 from inltk.inltk import setup
#       2
# ----> 3 setup('hi')
#
# /usr/local/lib/python3.6/dist-packages/inltk/inltk.py in setup(language_code)
#      31     loop = asyncio.get_event_loop()
#      32     tasks = [asyncio.ensure_future(download(language_code))]
# ---> 33     learn = loop.run_until_complete(asyncio.gather(*tasks))[0]
#      34     loop.close()
#      35
#
# /usr/lib/python3.6/asyncio/base_events.py in run_until_complete(self, future)
#     469         future.add_done_callback(_run_until_complete_cb)
#     470         try:
# --> 471             self.run_forever()
#     472         except:
#     473             if new_task and future.done() and not future.cancelled():
#
# /usr/lib/python3.6/asyncio/base_events.py in run_forever(self)
#     423         self._check_closed()
#     424         if self.is_running():
# --> 425             raise RuntimeError('This event loop is already running')
#     426         if events._get_running_loop() is not None:
#     427             raise RuntimeError(
#
# RuntimeError: This event loop is already running
# Done!

# %%
my_file = open("pos_text.txt", "r")
content = my_file. read()
print(content)
# Out:
# ﻿अब नए फीचर से इस तरह की गलतियां नहीं होंगी और अकाउंट को हैक करना बेहद मुश्किल हो जाएगा ।
# कंपनी के मुताबिक , एंड्रॉयड के लिए आए पेरिस्कोप में सभी कोर फीचर्स हैं जो यूजर्स द्वारा पसंद किये गए हैं ।
# पेरिस्कोप एप यूजर्स भी अडिशनल पुश नोटिफिकेशन सेटिंग्स अपने हिसाब से सेट कर सकते हैं जैसे फर्स्ट टाइम ब्रॉडकास्ट नोटिफिकेशन्स और शेयर नोटिफिकेशन्स ।
# पेरिस्कोप एप में रिज्यूम नोटिफिकेशन फीचर दिया गया है जो बहुत ही खास है ।
# इस फीचर के तहत यूजर ब्रॉडकास्ट के जरिए देखे जाने वाले वीडियो रूकने पर फिर वहीं से देख सकते हैं जहां वो रूका था ।
# इस फीचर के तहत ब्रॉडकास्टर का टाइम और मोबाइल डेटा दोनों की बचत होती है ।
# आपके स्मार्टफोन में ज्यादातर एप ऎसे ही हैं जिनसे आपको अपनी जेब का पैसा खर्च कर ही कुछ काम लिया जा सकता है , लेकिन एक ऎसी एप भी है जिसमें आपको ना केवल फ्री में रिचार्ज मिल सकता है बल्कि डिस्काउंट कूपन भी प्राप्त किए जा सकते हैं ।
# स्लिक इंटरफेस है ।
# मैसेंजर अब ब्लैकबेरी स्मार्टफोन तक ही सीमित नहीं है ।
# 3जी पर मैसेज डिलीवरी व्हाट्सप्प और आर्इमैसेज की तुलना में बहुत तेज है ।
# व्हाट्सप्प जैसा फीचर है ।
# यह शायद सबसे अच्छी बात है जो उन सभी यूजर्स के साथ हो सकती है जो प्लेटफॉर्म बदलना चाहते हैं लेकिन बीबीएम फ्रेंड्सलिस्ट उन्हें ऐसा करने से रोकती है ।
# चूंकि इसका गोइंग अच्छा था , अत : मैंने एप्प्ल एप्प स्टोर से बीबीएम को डाउनलोड कर लिया ।
# हालांकि इसके अधिकतर भाग सही स्टैंडर्ड रूप में दिखते हैं , फिर भी पूरे एप्प में साइड स्वाइप्स , एक्सेस और कार्यशैली का एक अन्य स्वरूप बढ़ा देते हैं ।
# स्क्रीन के नीचे दिया गया टैब आपको चैट्स , कॉन्टैक्ट्स और ग्रुप्स के बीच नेविगेट करने की सुविधा देता है ।
# आपकी रूचि बनाये रखने के लिए , इस एप्प में काले , आसमानी , नीले और सफेद रंग के मिश्रण से युक्त पर्याप्त विजुअल एलीमेंट्स उपलब्ध हैं ।
# इसके टेक्स्ट आधारित चैट का अनुभव ठीक वैसा ही होगा जैसा कि आप आशा करते है , चैट शुरू करने का वही तरीका और हर कॉन्टैक्ट के लिए इनडिविजुअल चैट विंडो ।
# अपने प्रतिस्पर्धियों के मुकाबले ज्यादा चैनल देता है ।
# अच्छी स्ट्रीमिंग क्वालिटी है ।
# मैसिव वीडियो लाइब्रेरी है ।
# ऐसी सर्विस शुरू करने वाला , यह तीसरा डायरेक्ट - टू-होम टेलिविजन सर्विस प्रोवाइडर है , और यह प्रयास बहुत ही प्रभावशाली है ।
# इसकी स्ट्रीमिंग की क्वालिटी बहुत हद तक आपके इंटरनेट कनेक्शन पर निर्भर करता है , और हर चीज सुव्यस्थित होने के कारण , टीवी चैनल बिल्कुल सही ढंग से देखे जा सकते हैं ।
# एयरटेल एप्प पर 150 चैनल देते हैं जो इसके किसी भी प्रतिस्पर्धी के मुकाबले अधिक है ।
# लाल और सफेद का कलर थीम कम्बिनेशन एयरटेल का बहुत ही सुंदर ट्रेडमार्क है ।
# वीडियो को फ्री दिखाता है ।
# मौजूदा डिजाइन निस्संदेह उपयोग और प्रेरणा से अधिक है ।
# हल्का चमकीला ग्राफिक्स अच्छा काम करेगा , जैसे कि टाटा स्कार्इ ने एवरीह्वेयर टीवी सर्विस को पैकेज किया ।
# लाइव टीवी इस एप्प के इस्तेमाल करने और उसके लिए भुगतान करने के पूरे काम का मेन प्वॉइंट है , और यह बताते हुए मुझे बहुत खुशी हो रही है कि इसका अनुभव बहुत ही अच्छा है ।
# आपको बस एक अच्छी स्पीड पर एक वार्इफार्इ या 3जी कनेक्शन की जरूरत होती है और स्ट्रीमिंग क्वालिटी भी अच्छी होती है ।
# डिटेक्टेड बैंडविथ के अनुसार , क्वालिटी को ऑटोमैटिकली मैनेज किया जाता है ।
# किसी स्मार्टफोन या टैबलेट के मामले में , यह स्ट्रीमिंग के लिए जरूरत से ज्यादा की क्वालिटी है ।
# 8 एमबीपीएस वार्इफार्इ कनेक्शन पर स्ट्रीमिंग बहुत सही होता है ।
# टाटा स्कार्इ के एवरीह्वेयर और डिश टीवी के डिश ऑन लाइन सर्विस के मुकाबले , यह बहुत अधिक है ।
# एयरटेल पॉकेट टीवी एप्प पर ऑन डिमांड सर्विस अलग अलग तरह के मूवीज की लाइब्रेरी देती है और वह बिगफ्लिक्स द्वारा पावर्ड होती है ।
# और इसका सबसे अच्छा भाग यह है कि मूवीज की पूरी लाइब्रेरी को बिना किसी अतिरिक्त चार्ज के स्ट्रीम किया जा सकता है ।
# 60 रूपये प्रति माह में लाइव टीवी स्ट्रीमिंग और ऑन - डिमांड सेक्शन में उपलब्ध एक मैसिव मूवी लाइब्रेरी , यह बुरा सौदा नहीं है ।
# बिल्कुल र्इमानदारी से , टीवी देखने के लिए आपके स्मार्टफोन को एक वैकल्पिक स्क्रीन बनाकर एयरटेल पॉकेट टीवी , ढेर सारी फ्लेक्सिबिलिटी और सुविधा देता है ।
# ' साइन ईजी एप ' आपके फोन या टैबलेट पर अपने डिजिटल डॉक्यूमेंट्स को डिजिटली साइन कर सकने की आजादी देता है ।
# इस एप की मदद से आप अपने हस्ताक्षर को रजिस्टर कर सकते हैं ।
# इसके बाद आईफोन 5एस पर फिंगप्रिंट सेंसर का उपयोग कर इसे डॉक्यूमेंट पर हस्तांतरित किया जा सकता है ।
# ' एंटर साइन ईजी एप ' के साथ आईफोन 5एस के उपभोक्ताओं की यह परेशानी खत्म हो जाती है ।
# इस एप की एक बड़ी खूबी यह है कि इसमें आपको बार बार डिजिटल हस्ताक्षर करने की जरूरत नहीं पड़ती ।
# बस एक बार साइन ईजी एप डाउनलोड करने के बाद आप यह डिजिटल हस्ताक्षर अपने आईफोन 5एस पर ड्रॉ करते हैं और बाद में फोन के टच आईडी सेंसर की मदद से कितनी भी बार इसका उपयोग किया जा सकता है ।
# शानदार ग्राफ़िक्स और कार का सूक्ष्म विवरण देने वाला यह गेम आपके एंड्रायड उपकरण पर अवश्य होना चाहिए ।
# एयरबोर्न एक बहुत शानदार रेसिंग अनुभव देता है , जहाँ रेस के आलावा आपको तेज़ गति के एरिएल स्टंट , नॉकडाउन और ड्रिफ्टिंग को भी करना होता है ।
# गेमलॉफ्ट द्वारा प्रस्तुत जीटी रेसिंग 2 एक अन्य शानदार दिखने वाला गेम है ।
# यह संगीत चलाने वाला एप सादा , बढ़िया , स्थिर और विश्वशनीय है , और यह आपके पास अवश्य होना चाहिए ।
# इसकी विशेषताओं में आसान इंस्टालेशन , साफ़ सुथरा यूजर इंटरफ़ेस , और अच्छी आवाज़ का स्तर शामिल हैं ।
# इसमें विशेष बेस और ट्रेबल नियंत्रण है ।
# इस एप में एंड्रायड होम स्क्रीन पर इस्तेमाल करने के लिए विजेट्स भी हैं , जो मीडिया चलाने को बहुत आसान बना देता है ।
# आईट्यून्स से आपके एंड्रायड फ़ोन पर संगीत ग्रहण करने की इसकी क्षमता इसे उन लोगों के लिए काफी सुविधाजनक बना देती है , जिन्होंने अपना सम्पूर्ण संगीत आईट्यून्स पर संग्रह कर रखा है ।
# इस एप से आप चित्रों को सीधे इन्स्टाग्राम नेटवर्क पर भेज सकते हैं , और यहाँ तक कि चित्रों को अपने फ़ोन में सुरक्षित भी कर सकते है ।
# यह एप इस्तेमाल करने में अब तक का सबसे आसान एप है , और बेहतरीन पैनोरमा तस्वीर लेने के लिए इसे सिर्फ दृश्य के आर पार घुमाने की आवश्यकता होती है ।
# सबसे अच्छी बात यह है कि यह मुफ्त है ।
# गेम आधारित प्रमोशनल कैंपेन इसपर आसानी से चलाए जा सकते हैं ।
# इसके साथ ही स्लोफो आपको सोशल होने की सुविधा भी देता है ।
# इसके अलावा इस एप्लिकेशन का बेहद अहम फीचर यह है कि इसपर आप अपने पसंदीदा ब्रांड को फॉलो कर सकते हैं और एक ही फीड पर आप उनके द्वारा चलाए जा रहे सभी कॉन्टेस्ट और अपडेट्स पढ़ सकते हैं ।
# प्रोफेशनल्स को भी स्लोफो उनके फॉलोअर्स बनाने और उसे बढ़ाने का मौका देता है ।
# स्लोफो एक मनोरंजक एप्लिकेशन है इसमें कोई दो राय नहीं है लेकिन अभी भी इसमें सुधार की आवश्यकताएं हैं ।
# इस ऐप की सहायता से आप अपने आप को स्वस्थ रख रकते हैं ।
# इंटरनेट मूवी डेटाबेस IMDb इस साइट पर हमें जरुर जाना चाहिए अगर आपने लम्बे समय से कोई मूवी या टीवी सिरिअल नहीं देखा है ।
# शुक्र है कि अप यह ऐप आपके स्मार्टफ़ोन पर आसनी से उपलब्ध है ।
# इस ऐप के माध्यम से आप कोई भी विडियो डाउनलोड कर सकते हैं और उसे दुनिया भर में अपने दोस्तों के साथ साझा कर सकते हैं ।
# इस ऐप के माध्यम से आप इन विडियोज़ को लगभग अलग अलग 20 भाषाओं में देख सकते हैं ।
# और इसे यूआई पर इस्तेमाल करना बेहद आसान है ।
# इस ऐप में एक फीचर है फीचर्ड टीईडी टॉक्स” इसके माध्यम से आप विडियोज़ का आनंद अपनी पसंद के अनुसार महत्ता और दिनांक के अनुसार उठा सकते हैं , इस ऐप में विडियोज़ को महता और डेट के हिसाब से रखा गया है ।
# यूट्यूब : इसे समझने में कोई ज्यादा परेशानी नहीं हैं कि मनोरंजन का पर्याय आज के समय में यूट्यूब है ।
# इसे इस्तेमाल करना बहुत ही ज्यादा आसान है , बिना किसी परेशानी के आप किसी भी विडियो को आसानी से इसके माध्यम से खोज सकते हैं ।
# इसमें एक सुंदर यूआई भी है और इसके द्वारा विडियो शेयर करना प्रसंता देता है ।
# आप इसके माध्यम से अपने पसंद के चैनल को सब्सक्राइब कर सकते हैं और अपने PC अकाउंट के साथ इस लिस्ट को सिंक भी कर सकते हैं ।
# हालांकि बड़ी स्क्रीन वाला फोन इस सर्विस के लिए अच्छा है ।
# सबसे पहले , अब गूगल ड्राइव एप्पलीकेशन Goggle Drive application यूजर्स को एप्पीलेकशन के अंदर अपने आप से सीधे ही स्प्रेडशीट को संपादन करने की सुविधा देगा ।
# यह निश्चित रूप से कई यूजर्स के बीच स्पैड्रशीट पर तेज और शानदार नियंत्रण की सुविधा देगा ।
# एप्लिकेशन में आईकान को बेहद ही सहज तरीके से पेश किया गया है ।
# पिछले पांच सालों के दौरान एप्पल आईओएस आपरेटिंग में बेहतर विकास देखने को मिला है ।
# म्यूजिक के मामले में तो आपको बहुत कुछ मिलेगा ।
# कंपनी के एप्स स्टोर पर आज एक से बढ़कर एक म्यूजिक एप्लिकेशन हैं ।
# ऐसे में आप एप्स स्टोर परगेम्स की बात करें तो आज स्मार्टफोन यूजर्स के लिए विभिन्न तरह की शैलियों वाले बहुत से गेम्स मौजूद हैं ।
# इन सब में से एक्शन गेम्स सबसे अधिक पसंदीदा और मजेदार माने जाते हैं ।
# यह हलका है ।
# यह ऑफ़लाइन काम करता है ।
# दिलचस्प गेम प्ले है ।
# आसान नियंत्रण है ।
# लेकिन कार्टून वॉर्स लिंक एक जाने माने पब्लिशर गेमविल का प्रॉडक्ट है , जो न केवल दूसरे गेम से अलग है बल्कि बेहद रोचक भी है ।
# कुल मिलाकर यह गेम बेहद मजेदार है , जिसकी मदद से यूजर्स घंटों तक मस्ती कर सकते हैं ।
# इसकी ग्राफिक क्वालिटी भी अच्छी है ।
# इस गेम के लिए न्यूनतम ग्राफिक्स की जरूरत होती है ।
# इतना ही नहीं , इन गेम के लिए सामान्य उपकरणों की जरूरत होती है ।
# कुल मिलाकर यह गेम एक बेहतरीन आइडिया है जो घंटों तक यूजर्स को अपने डिवाइस से जोड़े रख सकता है ।
# चूंकि प्लेयर्स इस प्रक्रिया में अपनी ड्राइंग के साथ ही अपनी शब्दावली में भी सुधार करने में सक्षम होते हैं , ऐसे में इसे खेलने में कोई खराबी नहीं है ।
# इस तरह से यह पजल लवर्स के लिए बेहतरीन गेम है ।
# ग्राफिक क्वालिटी अच्छि है ।
# अनलिमिटेड गेमप्ले और हार्डकोर एक्शन है ।
# रोल प्लेइंग गेम्स यानी आरपीजी एंड्रॉयड पर काफी पॉपुलर हो चुके हैं ।
# खूबियां : एक्शन से भरपूर गेमप्ले , लो एंड डिवाइस में भी चलने योग्य , आसान कंट्रोल , फ्री ।
# एक्शन से भरपूर गेमप्ले है ।
# लो एंड डिवाइस में भी चलने योग्य है ।
# आसान कंट्रोल है ।
# ऐप स्टोर से फ्री मिलता है ।
# ऑफलाइन होने पर काम करता है ।
# लैंडलाइन को भी खोज लेता है ।
# बिना व्यवधान का प्रदर्शन है ।
# नंबरों की मैन्युअल खोज उपलब्ध है ।
# ये बहुत ही हल्का है तथा इसके डाटा आपकी डिवाइस में अंदरूनी रूप से स्टोर रहते है , जिसके कारण आपको एक्टिव जीपीआरएस कनेक्शन , इस एप्प को प्रयोग करने के लिए नहीं लेना पड़ता है ।
# यह बहुत ही उपयोगी एप्पलीकेशन है ।
# इस्तेमाल करने में आसान है ।
# व्यावहारिक प्रयोग है ।
# डिफॉल्ट ब्राउजर के साथ तालमेल बिठाने में आसान है ।
# वजन में हल्का है ।
# इस एप्लीकेशन का लेआउट काफी साफ है और डाउनलोड लिंक को सीधे एप्लीकेशन में पेस्ट करने की सुविधा है ।
# जहां तक ब्राउजर की बात है , तो मूल ब्राउजर के साथ तो यह काफी बढ़िया तरीके से काम करता है , लेकिन ओपेरा जैसे ब्राउजर जिसमें इनबिल्ट डाउनलोड क्लाइंट होता है , वहां टर्बो डाउनलोडर कुछ खास उपयोगी नहीं है ।
# कुल मिलाकर यह एप्लीकेशन वैसे यूजर्स के लिए फायदेमंद है , जिन्हें अपने मोबाइल डिवाइस पर बड़ी फाइलों को डाउनलोड करना पड़ता है , और चूंकि यह एप्लीकेशन मुफ्त में भी उपलब्ध है ।
# इसके बाद आसानी से जब चाहें तब टिकट बुक कर लें ।
# गेम में कई स्‍टंट और अच्‍छे ग्राफिक दिए गए हैं ।
# गेमलॉफ्ट के अनुसर जीटी रेसिंग 2 में यूजर को रियल कार रेसिंग का अनुभव होगा ।
# पेंटैक्स के-500 डीएसएलआर , शौकिया फोटोग्राफी के लिए अच्छे फीचर्स और अच्छी कीमत का कैमरा है ।
# मजबूत बनावट और डिजाइन है ।
# पेन्टेक्स के-500 एक आकर्षक डीएसएलआर है ।
# कई अच्छे फीचर्स के साथ इसकी इमेज की क्वालिटी भी बेहद अच्छी है ।
# जो अपनी फोटोग्राफी स्किल्स बढ़ाना चहते हैं उनके लिए निकॉन या कैनन के साथ जाना ही अच्छा चुनाव होगा ।
# कम रौशनी या हाथ से तस्वीर लेते हुए संतुलन के साथ शार्प इमेज के लिए इसमें विशेष रूप से ' सेंसर - शिफ्ट स्टैबिलाइजेशन ' दिया गया है ।
# कंट्रोल्स , डायल्स और बटन्स बॉडी पर इस तरह फिट किए गए हैं कि आपको इनके प्रयोग में उलझन महसूस नहीं होती , यहां तक कि अगर आप निकॉन या कैनन डीएसएलआर के यूजर हैं तो भी कंट्रोल्स के प्रयोग में आपको ज्यादा वक्त नहीं लगता ।
# रबर आईकैप के साथ व्यू फाइंडर बेहद आरामदायक बनाया गया है ।
# 1050 एमएएच रिचार्जेबल लिथियम या 4 एए बैटरी काफी अच्छा फीचर है ।
# इंट्री लेवल के लिए अपने प्रतियोगियों के मुकाबले के-500 ज्यादा लाभकारी प्रीमियम नजर आता है ।
# इसमें बटन्स भी इस कीमत में आने वाले अन्य डीएसएलआर के मुकाबले ज्यादा दिए गए हैं ।
# इस कारण अन्य डीएसएलआर के मुकाबले इसमें ज्यादा कंट्रोल और फीचर की सुविधा से इनकार नहीं किया जा सकता ।
# पिक्चर क्वालिटी , रॉ RAW और जेपीइजी JPEG तो प्रभावित करता है , पर इसके अलावा भी एक बेहद लाभकारी फीचर इसमें है ।
# वह यह कि रॉ फाइल्स को इसमें आप सेव कर सकते हैं , और यह तब भी काम करता है जबकि आपने कैमरा में रॉ फॉर्मेट सेव का ऑप्शन सेट नहीं किया होता है ।
# स्पोर्टिंग इवेंट्स के लिए कभी - कभी फोटोग्राफी का शौक रखने वालों के लिए ईजी टू यूज है ।
# क्योंकि के-500 में पिक्चर आइएसओ 3200 ISO 3200 पर लिए जाते हैं , इसलिए इसकी तस्वीरें उच्च गुणवत्ता की होती हैं , इनमें धुंधलापन नहीं होता ।
# निकॉन डी3200 और कैनन 1200डी की तुलना में इसका तस्वीर - संतुलन अच्छा है ।
# ऑटो व्हाइट बैलेंस हर सिचुएशन में अच्छा काम करता है और इसपर अच्छी पिक्चर का भरोसा आप कर सकते ।
# पेंटैक्स के-500 डीएसएलआर : शौकिया फोटोग्राफी के लिए अच्छे फीचर्स और अच्छी कीमत का कैमरा है ।
# मजबूत बनावट और डिजाइन , 100-51200 के साथ आइएसओ का बड़ा रेंज 6 और एफपीएस ड्राइव मोटर इसकी खासियते हैं ।
# निकॉन ने पहली बार D5300 नाम से नया डीएसएलआर कैमरा लांच किया है जिसमें जीपीएस और वाईफाई कनेक्‍टीविटी का फीचर दिया गया है यानी आप कैमरे से सीधे अपनी तस्‍वीरें शेयर कर सकते हैं ।
# इसके अलावा कैमरे से टैबलेट और स्‍मार्टफोन में भी फोटो शेयर की जा सकती है ।
# वाईफाई की मदद से जहां कैमरे में फोटो शेयर की जा सकती है वहीं इसमें रिमोट कंट्रोल द्वारा फोटो शूट करने की सुविधा यूजर को मिलेगी ।
# दूसरे फीचरों पर नजर डालें तो निकॉन D5300 में 1920 x 1080 रेज्‍यूलूशन सपोर्ट के साथ 60 पिक्‍सल फुल एचडी रिकार्डिंग की सुविधा दी गई है ।
# नए मॉडल में ज्‍यादा आईएसओ रेंज दी गई है जिससे आप लो लाइट कंडीशन में भी अच्‍छी फोटोग्राफी कर सकते हैं कैमरे में 100 से 12,800 तक आईएसओ रेंज सेट की जा सकती है ।
# पेंटेक्‍स एमएक्‍स 1 प्‍वाइंट एंड शूट पेंटेक्‍स के नए प्‍वाइंट और शूट कैमरे MX - 1 में 12 मेगापिक्‍सल का सीएमओएस सेंसर लगा हुआ है साथ में 4 एक्‍स जूम और 3इंच की एलसीडी स्‍क्रीन दी गई है जो बेहतर फोटोग्राफ कैपेचर करती है ।
# जबकि एक्‍स 20 में एक्‍स ट्रांस सीएमओएस II प्रोसेसर लगा है जो ऑटो फोकस को और इंप्रूव करता है ।
# कैमरे में लगे सेंसर अंधेरे में ऑटोमेटिक एडजस्‍ट हो कर लाइट इंप्रूव कर लेते हैं ।
# इसके अलावा कैमरे में एपीएस सीएमओएस 20.3 मेगापिक्‍सल सेंसर लगा हुआ है जिसके साथ हाईब्रिड ऑटो फोकस सिस्‍टम इनबिल्‍ड है ।
# इसके अलावा ज्‍यादा देर तक फोटो कैपचरिंग करने के लिए कैमरे में प्रोलॉग बैटरी दी गई है ।
# कैमरे लगी स्‍क्रीन की सबसे बड़ी खासियत है इसकी स्‍क्रीन को 90 डिग्री तक मोड़ सकते हैं ।
# इससें आप पानी के अन्दर जाकर भी शानदार तस्वीरें खींच सकते हैं ।
# इसमें सबसे खास बात ये है पानी में उतरकर तस्वीरें खींचने पर भी इस कैमरा का कुछ नहीं बिगड़ता ।
# एचटीसी आरई एक एक्शन कैमरा है जिसमें और भी कई सारे ऎसे फीचर्स दिए गए हैं जो इसें शानदार कैमरा बनाते हैं ।
# यह एक्शन बंजी जम्पिंग , कैमरा वाटर राफ्टिंग और अन्य कई लोकप्रिय एक्शन स्पोर्ट्स के क्वक शॉट्स लेने में बहुत ही काम का साबित हो सकता है ।
# इसमें 18 सीन मोड्स तथा 10 से ज्यादा इफेक्ट के साथ - साथ पोट्रेट टच - अप टूल और फेस डिटेक्शन जैसे फीचर दिए गए हैं ।
# इस कैमरे की कीमत 10 हजार रूपए से थोड़ी ज्यादा है , लेकिन फीचर्स के मामले में यह बेहतर है ।
# दुनिया का पहला ऎसा कैमरा है जो 4के 60पिक्सल/50पिक्सल इमेजेज एसडी कार्ड में रिकॉर्ड करने में सक्षम है ।
# पेनासोनिक एचसी - एक्स1000 की सबसे खास बात ये है कि इससें 4के सिनेमा 4960 * 2160 पिक्सल , यूएचडी 3840 * 2160 पिक्सल और फुल एचडी1920 * 1080 पिक्सल की वीडियो रिकॉर्डिग की जा सकती है ।
# इसी के चलते यह प्रोफेशनल डॉक्यूमेंट्री शूटिंग और इवेंट्स शूटिंग के लिए सबसे शानदार कैमरा है ।
# दुनिया का पहला ऎसा कैमरा जो खींचता है लाजवाब तस्वीरें ।
# पेनासोनिक ने लॉन्च किया लेमिक्स जीएच 4 , शानदार तस्वीरें खींचने के साथ ही वीडियो भी करेगा शूट
# अब एक ऎसा अत्याधुनिक कैमरा आ चुका है जो लाजवाब क्वालिटी की तस्वीरें खींचने के साथ - साथ सबसे बढिया क्वालिटी के वीडियो भी शूट करता है ।
# लूमिक्स जीएच4 की सबसे खास बात ये है यह दुनिया का पहला ऎसा कैमरा है जो 4के वीडियो रिकॉर्डिंग करने में सक्षम है ।
# यही नहीं बल्कि लूमिक्स जीएच4 कैमरा मार्केट में मिलने वाले फुल एचडी कैमरों से 4 गुना अधिक शक्तिशाली है ।
# बहुत शानदार क्वालिटी के फोटो और वीडियो शूट करने वाले इस कैमरे में 16.05 मेगापिक्सल डिजिटल लाई एमओएस से ंसर दिया गया है ।
# सुस्पष्ट और विस्तृत इन्टरफेस है ।
# अच्छी बनावट और र्इयर टिप्स हैं ।
# स्पष्ट और झंकारयुक्त साउंड सिग्नेचर है ।
# हार्इ इंस्ट्रूमेंट डेंसिटी को संभाल सकता है ।
# इसका डिटेल , स्पष्टता , ऑडियो सेपरेशन ये सब इसे खरीदने योग्य बनाते हैं ।
# यह अलग - अलग प्रकार के जैसे - रॉक , मेटल और यहां तक कि इले​क्ट्रॉनिक म्यूजिक के साथ अच्छे से काम करता है ।
# कॉवन र्इएच2 के परफॉर्मेंस की सबसे आश्चर्यजनक और मजेदार बात यह है कि यह 25k हेडफोन्स के करीब है जो कि 8k बैंड के मुकाबले अधिक है ।
# यदि आप इसे खरीद सकते हैं तो इसके लिए जरूर जायें ।
# इसका आयाम इसलिए रोमांचक है क्योंकि इसमें हमेशा र्इएम1 जैसे जेम्स को खोजने की संभावना रहती है ।
# उसकी स्पष्टता और डिटेल कुछ ऐसी थी कि उसके लीग को थोड़ा अपडेट करने का वक्त था और तुलना के लिए थोड़े बड़े गन्स लाने की जरूरत थी ।
# इसके बॉक्स बंडल में एक कैरी केस था जिससे यह काफी सुंदर दिख रहा था ।
# जिसे एक बेहतर सील और यह बताने की जरूरत नहीं कि बेहतर आइसोलेशन होता है ।
# हालांकि एक फुल रेंज ड्राइवर के मुकाबले अधिक ड्राइवर्स का होना एक फीचर जैसा लगता है जो आज कल कानों में स्पोर्टी प्रतीत होता ।
# विभिन्न सोर्सेज से र्इएच2 के बारे में कोशिश करने के बाद , एक बात स्पष्ट है कि इसका डिटेल असाधारण है ।
# परफॉर्मेंस और सच्चार्इ वास्तव में उत्कृष्ट है ।
# फ्लैट रिस्पॉन्स वाले उत्साही लोगों जो अपने ऑडियो में बहुत बूम पसंद नहीं करते हैं के लिए यह हेडफोन बहुत ही प्यारा होगा ।
# इतना ही नहीं बल्कि फिसलर के इन प्रेशर कूकर में खाना बनाने की 140 विधियों समेत पोषण संबंधी जानकारी भी मौजूद है ।
# यदि आप शानदार और किफायती मिक्सर ग्राइंडर खरीदने की सोच रहे हैं तो ग्लेन मिक्सर ग्राइंडर जी एल4022 से बेहतर शायद ही कोई दूसरा हो ।
# ग्लेन मिक्सर ग्राइंडर जीएल4022 सबसे बेहतर तथा शानदार इसलिए हैं कि होम एप्लायंस की गुणवत्ता व कार्यक्षमता को जांच कर उन्हें रेटिंग देने वाली संस्था दी राइट च्वॉइस मैग्जीन ने इसें सबसे शानदार बताते हुए फाइव स्टार रेटिंग दिया है ।
# इस साल दी राइट च्वॉइस के जांचकर्ताओं कुलमिलाकर मिक्सर ग्राइंउर के 33 विभिन्न मॉडल्स को परखा ग्लेन मि क्सर ग्राइंडर जीएल4022 सबसे शानदार साबित हुआ ।
# परीक्षणकर्ताओं का कहना है कि इन 33 मॉडल्स में ग्लेन मिक्सर ग्राइंडर जीएल4022 की मिक्सिंग , चॉपिंग , ग्राइंडिग तथा कन्वेंसिंग में परफोरमेंस सबसे शानदार है ।
# बहुत ही आकर्षक डिजायन वाले ग्लेन मिक्सर ग्राइंडर जी एल4022 के जार भी स्पेशल ऑयल सील्स से बने है जो इसमें बनने वाले चूर्ण को बाहर नहीं आने देते ।
# इसमें 750 वॉट की पावरफुल मोटर तथा 3 स्पीड की सेटिंग दी गई जिसकी बदौलत शानदार तरीके से ग्राइंडिंग तथा मिक्सिंग होती है ।
# इस स्मार्ट मैट की सबसे खास बात ये है कि कोई भी इस पर होकर गुजरता है तो उसके बारे में यूजर्स को मैसेज कर बता देती है ।
# इस गद्दे की एक ओर खास बात ये है कि इस सोने के बाद आपको टीवी देखनी हो तो उसें चलाने के लिए उठकर जाने की जरूरत नहीं , क्योंकि इसमें वाय - फाय की सुविधा दी गई जिससें आप उसें कनेक्ट करते हुए चालू कर सकते हैं ।
# काटन का कहना है कि इस गद्दे बनाने में फोम और छोटे एयर बॉल से बनाया है , जो दूसरे गद्दों से बिल्कुल अलग तथा स्मार्ट है ।
# बलूगा बेड पर आएगी मनचाही नींद , सर्दी और गर्मी का अहसास नहीं होने देता है यह बेड ।
# रोटीयां बनाने वाली यह मशीन असल में एक रोबोट है जो महिलाओं को इस झंझट से मुक्ति दिलाने में सक्षम है ।
# ये AC से एक बड़े कमरा या हॉल को कूल करने के लिए काफी है ।
# ये एक 3 स्टार है AC जिससे बिजली की खपत कम होती है ।
# रिमोट की मदद से यूजर्स टाइमर , ग्लो लाइट बटन , ऑटो स्विंग जैसे फीचर्स का इस्तेमाल कर सकता है ।
# कम्पनी के मुताबिक यह डिवाइस बहुत कॉम्पैक्ट है और साथ ही यह अपनी पीढ़ी के पुराने डोंगल से 30 फीसदी छोटा है ।
# इसके साथ ही इसके वाई - फाई में कुछ बदलाव के साथ इसमें इजाफ़ा किया गया है , जिसके बाद इसके लैग और स्लटर काफी कम हो गए हैं ।
# इसके साथ इसमें डुअल फिल्टर प्रोटेक्शन दिया गया है , ताकि यूजर्स को कमरे में सांस लेने में आसानी रहे ।
# इसकी ऑडियो क्‍वालिटी शानदार है इसके लिए लैपटॉप में जेबीएल स्‍पीकर और डॉल्‍बी होम थियेटर के अलावा मल्‍टीपल स्‍टोरेज ऑप्‍शन दिया गया है ।
# लैपटॉप में एंटी ग्‍लेयर एचडी लिड स्‍क्रीन दी गई है ।
# लैपटॉप में फास्‍ट टाइपिंग के लिए एक्‍यूटाइप कीबोर्ड दिया गया है ।
# लैपटॉप जिसकी कीमत भी ज्‍यादा नहीं है साथ ही इसमें दिए गए फीचर भी आपको पसंद आएंगे ।
# एचपी पवेलियन dv6 6100 की सबसे खास बात है इसमें आप अपनी जरूरत के हिसाब से कोर आई3 , कोर आई 5 और कोर आई7 में कोई भी प्रोसेसर चुन सकते हैं ।
# जो शुरुआती कंप्‍यूटर यूजरों के लिए एक अच्‍छा विकल्‍प है ।
# इसके अलावा लैपटॉप में डॉल्‍बी एडवांस ऑडियो वी2 तकनीक दी गई है जो साउंड की क्‍वलिटी को और बढा देती है ।
# कम कीमत जरूरी सॉफ्टवेयर इनबिल्‍ड हैं बेहतर परफार्मेंस
# इस लैपटाप की खासियत है इसकर एंटी - रिफलेक्टिव स्क्रीन , मतलब यह कि इस पर काम करते हुए आंखों पर बहुत ज्यादा जोर नहीं पड़ेगा ।
# इसके अलावा 1366 गुणा 768 पिक्सल के रिजोल्यूशन के साथ हाइ डेफिनेशन एलईडी डिसप्ले बहुत अच्छा है ।
# फिल्में देखने अथावा वीडियो देखने का अनुभव इस लैपटाप पर काफी अच्छा है ।
# इसमें 500 जीबी की हार्ड डिस्क और दो जीबी रैम है जो 2.30 गीगाहर्टज इंटेल पेंटियम प्रोसेसर के साथ काम करने की स्पीड को बेहतर बनाता है ।
# फिल्मों , गेमिंग और वीडियो को प्राथमिकता देने वालों के लिए यह अच्छा विकल्प हो सकता है ।
# इंटेल प्रोसेसर अच्छी कार्यक्षमता है ।
# प्रदर्शन ही एक मैट लग रही है , तो उस पर काम और अधिक सुविधाजनक चमक और प्रतिबिंब के बिना चमकदार स्क्रीन से अधिक है ।
# ग्राफिक्स कार्ड स्थापित और समर्पित स्मृति के 2GB के साथ इंटेल HD असतत NVIDIA GeForce जी. टी. 740M है , अच्छा कर रहे हैं ।
# लेकिन इस तरह के एक मॉडल के एक घर कंप्यूटर के लिए एक शानदार विकल्प हो सकता है ।
# लेनोवो G500 उच्च स्तर के प्रदर्शन पर निकलता है जो निर्माता , विंडोज 8 , द्वारा निर्धारित है ।
# डिवाइस का सकारात्मक विशेषताओं HDMI के इनपुट , कूलर , काम पर कोई आवाज नहीं , एक सोने मोड ढक्कन बंद करने या सत्ता बटन दबाने में प्रवेश करने की क्षमता शामिल है ।
# इस अल्ट्राबुक में 10 प्वाइंट तक की मल्टी - टच विशेषता है और साथ ही इसकी स्क्रीन 360 डिग्री के आकार में पूरी घूम जाती है ।
# विभिन्न सुविधाओं वाले इस अल्ट्राबुक को लेनोवो ने 59,990 रुपये के दाम पर लांच किया है ।
# इस लैपटॉप में एक्यूटाइप की - बोर्ड लगाया गया है और साथ ही की - बोर्ड के ' की ' को काफी बेहतर डिजाइन और आकार दिया गया है जिसकी बदौलत टाइप करते समय आपको काफी अच्छा लगेगा ।
# लेनोवो सी260-9.5 इंच के डिस्प्ले वाले लेनोवो सी260 लैपटॉप को आल - इन-वन डिवाइस माना गया है क्योंकि यह आपके लिए काम के साथ - साथ मनोरंजन का साधन बनने में भी सक्षम है ।
# लैपटॉप लेनोवो आइडिया पैड Z510 एक रोमांचक वीडियो गेम के लिए अपने समय बिताना पसंद करते हैं , जो उन लोगों के लिए एकदम सही है ।
# लेनोवो महान मल्टीमीडिया क्षमताओं के साथ एक मॉडल के रूप में श्रृंखला में एक लैपटॉप प्रदान की गई है ।
# यह इस नोटबुक लेनोवो एक छवि मॉडल के लिए अधिक है कि माना जाता है , हालांकि यह बहुत अच्छा ग्राफिक्स कार्ड के साथ सुसज्जित है , वीडियो प्रोसेसर चौथी पीढ़ी के इंटेल HD , राम के छह गीगाबाइट है ।
# ध्वनि बहुत अच्छी गुणवत्ता है ।
# असाधारण और बकाया कुछ भी नहीं , मैट फिनिश और छूने के लिए सुखद ।
# बैकलिट कीबोर्ड एक अच्छा बोनस है रात में लैपटॉप के साथ काम कर रहे लोगों के लिए ।
# इसके साथ ही आसुस ने इस लैपटॉप में बेहतर चार्जिंग सिस्टम भी लगाया है ।
# भारत का यह पहला नोटबुक है जो लेटेस्ट 5वें जेनरेशन के इंटेल कोर आइ7 प्रोसेसर से लैस है ।
# इसमें जेस्च र , वॉयस और फेशियल रिक्गनिशन जैसी क्षमताएं भी हैं ।
# यह न केवल लैपटॉप है बल्कि यह टैबलेट के रूप में भी उपयोग किया जा सकता है ।
# ग्राहकों की सुविधा के लिए एसर वन को टैबलेट की तरह इस्तेमाल करने के लिए कंपनी डिवाइस के साथ एक की - बोर्ड भी उपलब्ध कर रही है ।
# इसके अलावा एसर वन में 6,000 एमएएच की बैटरी के साथ इंस्टा - गो पॉवर सेविंग फीचर भी डाला गया है जो इसकी बैटरी को जल्दी ड्रेन होने से बचाता है ।
# इसमें स्टोरेज स्पेस काफी है ।
# क्‍लासी बैकलिट कीबोर्ड है ।
# गेमिंग बेंचमार्क टेस्ट में इसका शानदार प्रदर्शन इसे सबसे आगे ला खड़ा करता है ।
# इसके अलावा इसमें फुल एचडी डिस्प्ले है , जो कि बहुत कम लैपटॉप्स में देखी जाती है ।
# गेमिंग लैपटॉप जिनकी प्राथमिकता है , उनके लिए यह एक बेहतरीन विकल्प है ।
# दोनों के गेमिंग परफॉरमेंस की तुलना से ये साबित होता है कि जेड500 का परफॉरमेंस जेड580 से बेहतर है ।
# एचपी एन्वी डीवी6 , आइडियापैड वाई500 की तुलना में स्लिम और हल्का है ।
# ये उन बहुत से लोगों को आकर्षित करेगा जिनके लिए हल्का लैपटॉप काफी मायने रखता है ।
# डीवी6 एक अच्छे गेमिंग परफॉरमेंस के साथ एक अच्छी बनावट वाला लैपटॉप है , जिसे खरीदारी करते समय ज़रूर ध्यान में रखना चाहिए ।
# यहाँ पर जितने भी लैपटॉप दिए गए हैं , उनमे से इसका कीबोर्ड और टचपैड सबसे बेहतर है ।
# इस नोटबुक की बनावट बेहतरीन है ।
# लेकिन इसमें लगे एएमडी रेडिओन एचडी7670एम ग्राफ़िक्स चिप का प्रदर्शन लाज़वाब है ।
# इसमें इसके चेसिस के आसपास ज़्यादातर प्लास्टिक का इस्तेमाल हुआ है , लेकिन इसकी क्वालिटी काफी अच्छी है ।
# इस कीमत के रेंज में इसका डिस्प्ले , इसके सभी प्रतिद्वंदियों से बेहतर है ।
# इसे एक बहुत शक्तिशाली अफोर्डेबल लैपटॉप कहा जा सकता है ।
# हाई - एंड एचपी नोटबुक्स की लुक्स हमेशा बेहतरीन होती है – अत्याधुनिक और एग्रेसिव लुक जो हर किसी को भाते हैं ।
# एचपी ने एन्वी डीवी6-7206टीएक्स के ज़्यादातर हिस्सों में मैट फिनिश दिया है जैसा की वो सामान्यतया अपने नोटबुक्स में नहीं करते हैं ।
# इसका कलर मिडनाइट ब्लैक मेटल है और मैं कहूँगा कि इसके कवर का ब्रश्ड मेटल फिनिश ज़बरदस्त है ।
# लेकिन ये ग्लॉसी एलिमेंट बहुत ज्यादा नहीं है , इसलिए इस पर धूल आदि के निशान ज्यादा नहीं दिखते और इसे व्यवस्थित रखना इतना मुश्किल नहीं लगता ।
# इसमें कोई शक नहीं कि एन्वी डीवी6 की बनावट शानदार है ।
# नार्मल टाइपिंग के लिए कीबोर्ड काफी स्मूथ है और हाथ रखने की जगह बिल्कुल सॉलिड है ।
# इसका कवर भी काफी मज़बूत दिखता है ।
# पूर्व में एचपी पविलियन डीवी6 रेंज फुली लोडेड और उत्कृष्ट परफ़ॉर्मर रहे हैं ।
# कीमत को ध्यान में रखते हुए हम ये कह सकते हैं कि ये वो सर्वोत्तम मशीन है जो आप इस कीमत में खरीद सकते हैं ।
# एचपी एन्वी डीवी6 के स्पेसिफिकेशन लिस्ट पर नज़र डालें तो ये काफी बेहतर मालूम होती है ।
# स्पेसिफिकेशन के आधार पर डीवी6 क्षमता में अपने प्रतियोगियों से काफी आगे और तीव्र मशीन नज़र आती है ।
# एन्वी डीवी6 का 15.6-इंच डिस्प्ले जेड580 की तुलना में काफी ब्राइट और क्रिस्प है ।
# इसमें 1टीबी का हार्ड ड्राइव है जो काफी स्टोरेज क्षमता प्रदान करता है ।
# एन्वी डीवी6 का शानदार परफॉरमेंस आपको खुश कर देगा ।
# सारे एप्स बहुत आसानी से खुलते और बंद होते हैं और मल्टीटास्किंग में किसी भी तरह की परेशानी सामने नहीं आती है ।
# चाहे आपको ऑफिस में इस्तेमाल करना हो या घर पर , दोनों ही परिस्थितियों के लिए यह एक बेहद सक्षम मशीन है ।
# वैसे तो एन्वी डीवी6 का ग्राफ़िक चिप जेड580 की तुलना में ज्यादा शक्तिशाली है और कुछ परीक्षणों में इसके अनुरूप एन्वी डीवी6 के बेहतर परिणाम भी सामने आये हैं ।
# जेड580 की तुलना में इसकी स्क्रीन ज्यादा ब्राइट और क्रिस्प है और इसमें रंग गहरे और बेहतर नज़र आते हैं ।
# एचपी एन्वी डीवी6 का कीबोर्ड भी जेड580 से काफी बेहतर है ।
# इस पर लम्बे समय तक टाइपिंग करना बहुत सुविधाजनक है ।
# हम कह सकते हैं कि ग्राफ़िक्स के मामले में डीवी6 एक मध्यम स्तर का एक काफी सक्षम लैपटॉप है जो बहुत से गेम्स को आसानी से चला सकता है ।
# इसका कीबोर्ड शानदार है , और इस पर टाइपिंग करना एक बहुत अच्छा अनुभव देता है ।
# आप इस लैपटॉप को प्रतिदिन के काम के लिए और हर मामले में शानदार परफॉरमेंस के लिए खरीद सकते हैं ।
# सबसे अहम् बात ये है की डिज़ाइन और लुक्स के मामले में ये लेनोवो जेड580 से कहीं आगे है ।
# इसे निश्चित रूप से एक बेहतर चुनाव कहा जा सकता है ।
# कुल मिलाकर इसकी परफॉरमेंस काफी अच्छी कही जा सकती है ।
# इस कीमत में उपलब्ध अन्य विकल्पों पर नज़र डालें तो इसका लुक और फील काफी बेहतर है ।
# स्लिम बनावट के साथ शानदार गेमिंग क्षमता इसे एक बेहतरीन लैपटॉप बनाती है ।
# इसकी डिस्प्ले क्वालिटी काफी अच्छी है ।
# टेक्स्ट बहुत अच्छी तरह से दिखाई देते हैं और डिस्प्ले को ज़्यादातर कोणों से देखा जा सकता है ।
# इसका डिस्प्ले बहुत रिफ्लेक्टिव नहीं है जिससे इसे इस्तेमाल करना काफी आरामदेह रहता है ।
# ग्राफ़िक्स बेंचमार्क टेस्ट में लेनोवो आइडियापैड जेड500 का परफॉरमेंस बेहद शानदार है ।
# इसमें एनवीडिया जीफ़ोर्स जीटी645एम ग्राफ़िक्स है और यह परफॉरमेंस में आइडियापैड जेड580 से काफी आगे है जिसमे एनवीडिया जीफ़ोर्स जीटी630एम ग्राफ़िक्स है ।
# यह ना सिर्फ जेड580 से आगे रहता है , बल्कि सारे ग्राफ़िक्स बेंचमार्क टेस्ट में ये अपने सभी प्रतिद्वंदियों को काफी पीछे छोड़ देता है ।
# ग्राफ़िक्स में जेड500 का प्रदर्शन लाज़वाब है और इस दृष्टिकोण से इसे एक बेहतरीन गेमिंग नोटबुक कहा जा सकता है ।
# बैटरी के परफॉरमेंस टेस्ट में लेनोवो आइडियापैड जेड580 सबसे आगे रहता है ।
# लेनोवो आइडियापैड जेड500 में बहुत सी अच्छी बातों का सम्मिश्रण है - अच्छी बनावट , स्लिम लुक , अच्छा डिस्प्ले , बहुत अच्छा परफॉरमेंस , शानदार गेमिंग क्षमता और उम्मीद से बेहतर बैटरी लाइफ ।
# इस कीमत पर , बहुत सी अच्छी विशेषताओं के कारण ये लैपटॉप निश्चित रूप से एक बढ़िया विकल्प साबित होता है ।
# आसुस एफ202ई विवोबुक अपने काफी कॉम्पैक्ट साइज़ में बहुत अच्छा परफॉरमेंस देता है ।
# इसका आकार काफी हद तक एक अल्ट्राबुक की तरह कॉम्पैक्ट है ।
# विवोबुक एफ202ई की बेहतरीन बनावट इसकी खास विशेषता है ।
# इसमें एक बहुत अच्छा कीबोर्ड भी दिया गया है ।
# यह उनके लिए एक बहुत अच्छा लैपटॉप है जो या तो अपना पहला लैपटॉप खरीद रहे हों , या जिनके लिए पोर्टेबिलिटी काफी मायने रखती है ।
# उम्मीद के मुताबिक 11.6-इंच डिस्प्ले साइज़ के हिसाब से विवोबुक एफ202ई काफी कॉम्पैक्ट है ।
# यह लैपटॉप पीछे की तरफ थोड़ा सा मोटा और आगे की तरफ थोड़ा पतला है , इससे कीबोर्ड थोडा ऊंचा रहता है और जिससे टाइप करने में आराम रहता है ।
# जैसे ही आप विवोबुक को बॉक्स से निकालेंगे , आप आश्चर्य में पड़ जायेंगे की इसकी बनावट कितनी अच्छी है ।
# इस लैपटॉप में यह फिनिश देना काफी स्वागतयोग्य है ।
# कवर खोलने पर इसका साफ़ - सुथरा कीबोर्ड काफी आकर्षक दिखाई देता है ।
# जगह के हिसाब से की - स्पेसिंग बहुत अच्छी है और इसमें सबसे अच्छी बात टाइपिंग के समय इसका सर्वोत्तम ट्रेवल और तेज़ की रिस्पोंस है ।
# विवोबुक एफ202ई के टचपैड के आकार ने हमें थोडा आश्चर्य में डाला , इसका आकार हमारी उम्मीद से कही ज्यादा बड़ा है ।
# हमने इसे इस्तेमाल करने में काफी आरामदेह पाया ।
# और इसलिए एक अच्छा कीबोर्ड और टचपैड काफी मददगार साबित होता है ।
# हमें ख़ुशी है कि इस लैपटॉप में रैम पर्याप्त मात्रा में दिया गया है ।
# सामान्य कामकाज में इसका परफॉरमेंस काफी अच्छा है ।
# एप्स काफी तेज़ी से खुलते हैं और बहुत सी स्थितियों में इसके खुलने में समय नहीं लगता है ।
# मैकबुक का यह नया आया संस्करण अब तक का सबसे पतला मैकबुक है जिसकी मोटाई महज 13.1 एमएम है ।
# यह दिखने में काफी आकर्षक लगता है ।
# डेल ने भारत में दो नए ऎसे दमदार नोटबुक लॉन्च किए हैं जो शानदार परफोर्मेश वाले हैं ।
# ये दोनों ही लेपटॉप रगेड हैं जिसके चलते इन्हें बहुत खराब हालात या माहौल में भी इस्तेमाल किया जा सकता है ।
# रगेड परफोर्मेश वाले होने के साथ डेल के इन लैटिटयूड लेपटॉप्स में की स्क्रीन को फि्लप अपनी सहूलियत के अनुसार सेट किया जा सकता है ।
# इन कै मरों से आसानी से चैटिंग और दूसरे प्रोग्राम शूट किए जा सकते हैं ।
# लेपटॉप और टेबलेट दोनों एकसाथ की लेने की इच्छा रखने वालों के लिए यह सबसे अच्छा मौका है ।
# अगर आप 50,000 रूपये के आस - पास का लैपटॉप चाहते हैं , तो लेनोवो आइडियापैड जेड500 आपके लिए एक बेहतरीन विकल्प हो सकता है ।
# बैटरी के परफॉरमेंस टेस्ट में लेनोवो आइडियापैड जेड580 सबसे आगे रहता है और इसका क्षमता 199 मिनट है ।
# कवर खोलने पर इसका साफ़ - सुथरा कीबोर्ड काफी आकर्षक दिखाई देता है ।
# आसुस विवोबुक एफ202ई के 11.6-इंच डिस्प्ले साइज़ के कारण यह लैपटॉप काफी छोटा , हल्का और पोर्टेबल है ।
# इसका टचस्क्रीन एक अतिरिक्त लाभ है , लेकिन एक नोटबुक में टचस्क्रीन के इस्तेमाल की बहुत कम ज़रूरत पड़ती है ।
# इसके डिस्प्ले में टेक्स्ट बहुत अच्छी तरह से दिखाई पड़ता है ।
# रंग काफी गहरे हैं और ब्लैक लेवल इस कीमत के रेंज में सर्वोत्तम में से एक है ।
# इसमें विंडोज 8 64-बिट ऑपरेटिंग सिस्टम है , लेकिन अच्छी बात ये है कि इसमें बहुत सीमित प्रीलोडेड सॉफ्टवेर दिए गए हैं जिससे मशीन बोझिल नहीं होती ।
# इसका बूट टाइम अच्छा है और ये कोर आई3 वर्ज़न वाले एचपी पविलियन जी6 के स्तर का है ।
# ऑफिस में इस्तेमाल की स्थिति में हमने इस पर क्रोम ब्राउज़र के बहुत से टैब्स खोले और कई माइक्रोसॉफ्ट वर्ड डॉक्यूमेंट और एक्सेल स्प्रेडशीट्स के साथ बैकग्राउंड में आइट्यून्स को भी चलाया , लेकिन हमें इसके परफॉरमेंस में कोई कमी नहीं दिखाई दिया ।
# विवोबुक एफ202ई की कीमत के रेंज में आपको 13-इंच और 15-इंच के बहुत से लैपटॉप मिल सकते हैं , लेकिन अगर आपकी प्राथमिकता एक अच्छी बनावट वाला पोर्टेबल लैपटॉप है , तो एफ202ई एक बेहतरीन विकल्प है ।
# साथ ही यह IPS डिस्प्ले हैं जिनमें आपको बढ़िया व्युविंग एंगल्स मिल रहे हैं ।
# यह काफी मज़बूत और भारी है ।
# चिप कंप्यूटर की कीमत इतनी सस्ती होने के पीछे का कारण इसमें लगा सस्ता चाइनीज कोर है जो एक टेबलेट से लिया गया है ।
# चिप कंप्यूटर रास्पबेरी पीआई2 से भी सस्ता है ।
# यह अब तक का सबसे पतला मैकबुक है ।
# इसमें 12 इंच की रेटिना डिस्पले स्क्रीन लगी है ।
# इन नोटबुक्स को ऑयल और माइनिंग साइट्स पर तापमान बहुत अधिक होता है और मिलिट्री सर्विस के लिए सियाचिन , लद्दाख में तापमान बहुत कम पाया जाता है वहां भी बहुत ही आसानी से इस्तेमाल किया जा सकता है ।
# डेल का इन वारटप्रूफ रगेड लेपटॉप20 डिग्री तथा 60 डिग्री तापमान में भी देते हैं शानदार परफार्मेस ।
# एचपी के हाई - एंड लैपटॉप्स हमेशा बहुत अच्छे होते हैं ।
# आइडियापैड जेड580 की परफॉरमेंस शानदार है और एन्वी डीवी6-7206टीएक्स इसके काफी करीब रहता है ।
# एक बार ऐसा कर लेने के बाद एन्वी डीवी6 का शानदार परफॉरमेंस आपको खुश कर देगा ।
# सबसे अहम् बात ये है की डिज़ाइन और लुक्स के मामले में ये लेनोवो जेड580 से कहीं आगे है , इसे निश्चित रूप से एक बेहतर चुनाव कहा जा सकता है ।
# ये भारत के सबसे सस्ते लैपटॉप्स में से एक है ।
# कंपनी का ऐसा दावा है कि SATA 6Gbit / s SSD हार्ड डिस्क दूसरी ट्रेडिशनल हार्ड डिस्क से छह गुना ज्यादा तेज है ।
# कंपनी ने इस डिवाइस की बैटरी भी दमदार दी है ।
# इसे नया wedge शेप दिया गया है , जो ठोस एल्युमिनियम का है ।
# इसमें रैटिना डिस्प्ले , प्रेशर - सेंसिटिव फोर्स टच ट्रैकपैड के साथ कई अन्य हाईटेक फीचर्स दिए गए हैं ।
# पहले वर्जन के मुकाबले नए वर्जन में बेहतर डिजाइन है ।
# बाकी टू इन वन से विपरीत माइक्रोमैक्स लैपटैब में सॉलिड कीबोर्ड है ।
# 1.8 GHz के क्वाड - कोर इंटेल एटम प्रोसेसर के साथ इस टैबलेट में 2GB रैम है जो मल्टीटास्किंग के लिए बेहतर साबित हो सकती है ।
# इसकी स्क्रीन HD से दोगुना ज्यादा बेहतर क्वालिटी की है ।
# HP इलाइटबुक 1020 हर तरह के यूजर्स के लिए शानदार डिवाइस है ।
# ये दुनिया की सबसे हल्की बिजनेस नोटबुक है ।
# इस डिवाइस में पावर कीबोर्ड दिया गया है ।
# ' प्रीमियम मेटल ' डिवाइस में की - बोर्ड के साथ 10.1 इंच का टचस्क्रीन डिस्प्ले दिया गया है ।
# टच स्क्रीन को सुविधा के अनुसार 360 डिग्री घुमाया जा सकता है ।
# यह अब तक का सबसे स्लिम क्रोमबुक है इसकी थिकनेस सिर्फ 15mm है ।
# आप इसे किसी भी डिस्प्ले में प्लग करके उस डिस्प्ले को कम्प्यूटर की तरह इस्तेमाल कर पाएंगे ।
# यह स्कूल में या बिजनेस कॉन्फ्रेंस जेसे कामों में काफी यूजफुल हो सकता है ।
# ये आपके सिस्टम का डाटा और एनर्जी दोनों ही सेव करता है ।
# इस लॉक को लगाने के बाद आप बेफिक्र घूम सकते हैं ।
# सूचना प्रौद्योगिकी कंपनी एसर ने दुनिया का सबसे पतला लैपटॉप पेश किया है ।
# यह अत्यंत पतला और हल्का है , यह दूसरे लैपटॉप कारोबारियों के लिए मानक तय करता है ।
# नए लैपटॉप में पॉवरफुल प्रोसेसर , ग्राफिक सपोर्ट और सुपीरियर क्‍वालिटी का ऑडियो सपोर्ट दिया गया है ।
# एक ऐसा फ़ोन जिसमें है एक शानदार की पैड और ज़बरदस्त स्क्रीन ।
# ये फ़ोन एलटीई रेडी है और इसे ख़ूबसूरती से डिज़ाइन किया गया है ।
# इस नए फ़ोन का ब्राउज़र 3 गुना ज़्यादा फ़ास्ट है ।
# बोल्ड 9900 के मुक़ाबले इसमें 60 % ज़्यादा स्क्रीन स्पेस है और 50 % ज़्यादा बैटरी लाइफ़ है ।
# इसकी 5.5 इंच वाली 720पी की स्क्रीन आपको भाएगी ।
# इससे ली गई पिक्चर्स काफी अच्छी होती हैं ।
# कम रोशनी में भी इसका कैमरा अच्छी एचडीआर इमेज लेता है ।
# इसका 5 मेगापिक्सल का फ्रंट कैमरा भी काफी अच्छा है ।
# इससे अच्छी सेल्फी ली जा सकती है ।
# रेडमी नोट 4जी हमें पसंद आया ।
# प्राइस टैग तो जबरदस्त है ही ।
# फोन में बढ़िया डिस्प्ले है ।
# इसका एंड्रॉयड फंक्शन भी अच्छा है तो इस फोन को हम ' मस्ट - बाय ' का टैग देंगे ।
# वैसे यू यूरेका न तो कुछ ज्यादा ही स्लिम है और न ही वजन के मामले में काफी हल्का है ।
# इसकी संरचनात्मक खूबसूरती आपको माइक्रोमैक्स के अन्य फोन्स के मुकाबले भाएगी ।
# इसके चारों ओर के किनारे को थोड़ा उठा हुआ बनाया गया है ताकि किसी भी तरह की स्क्रैच से बचा जा सके ।
# साइज में दिए गए पावर और वॉल्यूम बटन्स आराम से ऑपरेट हो जाते हैं ।
# इसका स्क्रीन रेजॉल्यूशन हमें पसंद आया- 720x1280 पिक्सल ।
# जब हमने इस बाबत चेक किया तो रिजल्ट्स काफी पॉजिटिव मिले ।
# दिन प्रतिदिन के इस्तेमाल में यह फोन एकदम बढ़िया है ।
# यह बेहद परिष्कृत फोन है और ईमानदारी की बात तो यह है माइक्रोमैक्स के पिछले साल डेढ़ साल में आए बाकी फोन्स के मुकाबले इसे हाथ में लेना , यूज करना काफी बेहतर अनुभव है ।
# एक खास बात यह कि सूरज की रोशनी में भी आप इसे ' पढ़ ' सकते हैं ।
# इसका इन - बिल्ट स्पीकर अच्छा है और साउंड क्वॉलिटी में औसत से बेहतर है ।
# हमारे मुताबिक इसका कैमरा एकदम बढ़िया निकला ! इससे ली गई तस्वीरों की इमेजेस बेहतरीन थीं ।
# हमने जो क्लोज अप तस्वीरें लीं , वे जबरदस्त निकलीं और दिन की रोशनी में ली गई तस्वीरें इतनी शार्प थीं कि फोकस पॉइंट पर यदि आप किसी डेस्कटॉप से 100 परसेंट जूम भी करके भी देखें तो वे लाजवाब लगेंगी ।
# क्लोज अप के मुकाबले चौड़े फ्रैम्स बेहतर रहे ।
# इस फोन के मामले में साइनोजन ऑपरेटिंग सिस्टम 11 का होना एक बड़ा प्लस पॉइंट है ।
# सबसे अच्छी बात इस फोन के संदर्भ यह रहेगी कि रेडमी नोट का 4जी वर्जन इससे 1 हजार रुपए महंगा है , और इसका 4जी होते हुए अपेक्षाकृत सस्ता होने की वजह से लोग इसकी ओर मुढ़ेंगे ।
# यह फैबलेट कागजी आंकड़ों पर डुअल कोर 14 जीएचजेड प्रोसेसर , 5 इंच की स्क्रीन और 5 मेगापिक्सल के कैमरे सहित बहुत आशाजनक लगता है ।
# शानदार परफार्मेंस है , बहुत अच्छी बैटरी लाइफ है , पकड़ने में अच्छा है ।
# स्पाइस स्टेलर होराइजोन Spice Stellar Horizon में बहुत अच्छी स्पेसिफिकेशन्स हैं जैसे 5 इंच का डिसप्ले जिसका 800x480 पिक्सल रिजॉल्यूशन में , 5 मेगापिक्सल का रियर कैमरा फ्लैश सहित , फ्रंट कैमरा , 1Ghz डुअल कोर प्रोसेसर आधारित मीडियाटैक Mediatek चिपसेट , 512 MB RAM और 2400 mAh बैटरी ।
# सोनी की एक और अच्छी रचना जो कि मात्र देखने योग्य ही नहीं है ।
# चमकदार और साफ एलसीडी डिसप्ले है और बैटरी , कैमरा , साउंड आउटपुट अच्छे हैं ।
# अच्छी बैटरी लाइफ , एप्पलीकेशन का बेहतरीन संग्रह है अौर बेहतरीन टच स्क्रीन भी है ।
# फोन में अच्छा मल्टीमिडिया , पुश मेल push mail सेवा दोहरे मेमोरी कार्ड स्लॉट तथा 2.8 इंची कैपेसिटिव टच स्क्रीन के साथ - साथ फीचर्स का पूरा जखीरा लगा है ।
# डिसप्ले , अच्छा बैकअप अौर सहज इंटरफेस ।
# एक्सपेरिया सोला एंड्रॉयड स्मार्टफोन कीमत के लिहाज से रोमांचकारी और खास बात यह है कि इसमें फ्लोटिंग टच स्क्रीन डिसप्ले दिया गया है ।
# नोकिया 808 प्योरव्यू एक ऐसा कैमरा फोन है जिसमें है विस्मयकारी फोटो देने की क्षमता , लंबी बैटरी लाइफ और शानदार ऑडियो प्लेबैक के साथ रिकार्डिंग का अनुभव ।
# शानदार कैमरा क्वालिटी और विडियो रिकार्डिंग , साउंड और ऑडियो रिकार्डिंग क्वालिटी से भरपूर लंबी बैटरी लाइफ है ।
# नोकिया 808 प्योरव्यू Nokia 808 PureView कैमरा प्रधान नोकिया एन 8 Nokia N8 का सच्चा उत्तराधिकारी है और यह इस से एक लंबी छलांग भी है ।
# नोकिया एन8 Nokia N8 2010 में लांच होने के बाद से अपने 12 मेगापिक्सल के इमेजिंग सेंसर के बल पर कैमरा फोन सेगमेंट पर राज कर रहा है ।
# 41 मेगापिक्सल के इमेज सेंसर के अतिरिक्त नोकिया Nokia इमेजिंग इंजिनियर्स ने ऑप्टिक्स और फ्लैश पर भी पूरा ध्यान दिया है ।
# स्क्रीन की टच और इमेज क्वालिटी अच्छी है , बटेरी डेढ़ दिन तक चलता है , पर्फोर्मांस भी बहुत अच्छा है , पकड़ने में भी आसान है ।
# इस फोन की एक खास बात इसमें लगा 13 मेगापिक्सल्स का कैमरा है ।
# यह चटख रंगों और शार्प डीटेल वाले शानदार फोटो लेता है ।
# पिछला पैनल ऐल्युमिनियम का बना है और इसे निकाला नहीं जा सकता है , इसकी वजह से फोन मजबूत और प्रीमियम लगता है ।
# ठीक - ठाक कीमत पर डूडल 2 बड़ी स्क्रीन का बढ़िया एक्स्पीरियंस देता है ।
# कुलमिलाकर यह एक काफी अच्छा फोन है जो लगातार अच्छा परफॉर्म करता है और बिना किसी लैग या रुकावट के चलता है ।
# कैमरे का सबसे रोचक फीचर ऑप्टिकल इमेज स्टेबलाइजेशन है जो कि शानदार क्वालिटी के एचडी विडियो को रिकार्ड करने की सुविधा देता है ।
# लूमिया 820 Lumia 820 बेहतर साउंड आउटपुट के लिए डॉल्बी हेडफोन साउंड के साथ आता है ।
# लिनोवो S60 का सेल्‍फी कैमरा 5 मेगापिक्‍सल का है जिसमें फिक्‍स फोकस भी दिया गया है ।
# लूमिया 540 , कम दाम में ज्‍यादा काम ।
# ड्युल सिम ऑप्‍शन के साथ फोन को 10,199 के आकर्षक दाम में लांच किया गया है ।
# इसके साथ कुछ शानदार ऑफर भी मिल रहे हें ।
# लूमिया 540 के साथ एयरटेल सिम में 2 महिनों तक डबल डेटा भी मिलेगा यानी इन ऑफरों को देखकर आप ये कह सकते हैं आम के आम गुठलियों के भी दाम ।
# इस स्‍क्रीन की खास बात है अगर आप किताबें पढ़नें के शौकीन है तो फोन में देर तक ढेरों ईबुक पढ़ सकते हैं ।
# इस स्मार्टफोन का डिजाइन यूनिबॉडी है , जो इसे बहुत सॉलिड लुक और फील देता है ।
# यह हाई क्वालिटी के पॉलिकार्बोनेट से बना है , जो इस कीमत में बहुत बड़ी बात है ।
# मल्टी कलर्ड वैरिएंट निश्चित रूप से अपना प्रभाव छोड़ते हैं पर मैट फीनिश और मटीरियल जो इसे बनाने में प्रयोग किया गया है वो लुक और फील में इसे हाइ - एंड लूमिया डिवाइस के करीब रख देता है ।
# एमआई 4 आई में डिस्प्ले स्क्रीन 5 इंच फुल एचडी है ।
# यहां ऑन - स्क्रीन एक बटन एक्स है , जो आपको एप्स को किल करने और रैम को फ्री करने की सहूलियत देता है ।
# जियाओमी ने दावा किया है कि एमआइयूआइ 6 भाषाओं - हिंदी , बंगाली , कन्नड़ , तेलुगू , मलयालम , तमिल को सपोर्ट करता है , मगर हमने सातवीं भाषा मराठी को भी सेटिंग मेन्यु में पाया ।
# जब म्यूजिक सुन रहे हो , मूवी देख रहे हो या कॉल कर रहे हो तो उस दौरान लाउडस्पीकर अच्छा काम करते हैं ।
# जियाओमी एमआइ 4आइ में 13 मेगापिक्सल का रियर कैमरा है , जो आउटडोर में बहुत अच्छी पिक्चर्स कैप्चर करता है ।
# अच्छी सेल्फी के साथ - साथ वीडियो कॉलिंग भी की जा सकती है ।
# इनबिल्ट माइक ऑडियो के लिए अच्छा काम करते हैं ।
# डुअल टोन एलइडी फ्लैश अच्छा काम करती है सब्जेक्ट पर लाइटनिंग करके ।
# एमआइ 4आइ में ब्युटिफिकेशन फीचर दिया गया है , जो रिंकल और फेस के अन्य दाग - धब्बों को रिमूव करके सेल्फी व पिक्चर्स के मजे को दोगुना बना देता है ।
# डिस्प्ले में ऑटो ब्राइटनेस सेट की गई है और फोन 3जी डाटा कनेक्शन पर भी सम्मोहित करता है , जब ऑटोमेटिक एप अपडेट्स को डिसेबल कर देता है ।
# स्क्रीन बड़ा , बोल्ड व वाइब्रेंट है ।
# इसमें फ्रंट फेसिंग स्पीकर्स और वाइड एंगल्स हैं सिसे 6 इंच के स्क्रीन पर वीडियो देखना मनोरंजक है ।
# गूगल ने इस स्मार्टफोन में बेहतर ऑडियो के लिए फ्रंट पैनल में दो स्पीकर दिए हैं ।
# एमआइ 4आइ जियाओमी अपने आप में एक अन्य विजेता डिवाइस है ।
# इस फोन में स्टनिंग स्क्रीन के साथ ग्रेट बिल्ट क्वालिटी उपलब्ध है ।
# इतनी कम कीमत में इतने अच्छे स्पेसिफिकेशन फीचर के साथ इसे खरीदना अपने आप में एक अच्छा अनुभव ही साबित होगा ।
# फ्यूल 60 का यूएसपी इसका बैटरी बैकअप ही है ।
# इसकी 4000 एमएएच की बैटरी इसे विशेष बनाती है ।
# एक सिंगल चार्ज पर यह एक दिन से ज्यादा साथ निभाती है ।
# एक घंटे के विडियो प्लेबैक पर 10 प्रतिशत बैटरी खपत होती है और गेम्स खेलने के दौरान भी लगभग इतना ही खपत है अर्थात नार्मल ब्राइटनेस के साथ चार घंटे तक यूट्यूब वीडियो का आनंद भी लिया जा सकता है ।
# लावा के आयरिस फ्यूल 60 स्मार्टफोन की खासियत इसकी दमदार बैटरी लाइफ है ।
# 1 जीबी के रैम की वजह से इसका परफार्मेंस काफी अच्छा है ।
# कुल मिला कर लावा आयरिस फ्यूल 10,000 रुपये तक के स्मार्टफोन कैटेगरी में मिलने वाला बेहतर कैमरा है ।
# साथ ही बैटरी बैकअप के लिहाज से काफी अच्छा डिवाइस है ।
# मोटा व भारी होने के बावजूद यह स्मार्टफोन अच्छे लुक्स व बेहतर डिजायन वाला है ।
# परफार्मेंस की बात करें तो अपने टक्कर वाले हैंडसेट्स के मुकाबले यह बढि़या है इसलिए यदि आप लंबे बैटरी लाइफ वाले स्मार्टफोन की खोज में हैं तो आयरिस फ्यूल 60 आपके लिए बेहतर ऑप्शन है ।
# इसकी हर चीज इतनी आसान है कि यूजर को इसे कंट्रोल करने को एक बूंद पसीना भी नहीं बहाना पड़ेगा ।
# ...
# जबरवान पहाड़ियों की तलहटी में स्थित ट्यूलिप गार्डन में खिलने वाले सफेद , पीले , नीले , लाल , गुलाबी , ऑरेंज आदी रंग के ट्यूलिप के फूल आपको मोहित कर देगा ।
# सतरंगी ट्यूलिप के फूलों से सजा ट्यूलिप गार्डन घाटी में पर्यटकों के आकर्षण का एक प्रमुख केंद्र बन गया है ।
# कश्मीर अपनी प्राकृतिक सुंदरता के लिए प्रसिद्ध है और ट्यूलिप इसकी सौंदर्य को कई गुणा बढ़ा देता है ।
# 4K डिस्प्ले क्वालिटी का मतलब है HD से 8 गुना बेहतर डिस्प्ले क्वालिटी वाला डिवाइस ।
# कुल मिलाकर कहा जाए तो ये अभी कमर्शियल टीवी में सबसे बेस्ट क्वालिटी है ।
# इस टीवी में नॉइस रिडक्शन फीचर और SRS साउंड क्वालिटी सिस्टम है जो यूजर्स को बहुत अच्छी साउंड क्वालिटी देता है ।
# माइक्रोमैक्स टीवी का 49 इंच वाला मॉडल थोड़ा ज्यादा एडवांस फीचर्स के साथ आता है ।
# इसके अलावा 0.78 cm का स्लिम मेटल बेजल स्क्रीन की साइड बॉडी - bezel है ।
# पहले जहां एप्पल का पोर्टेबल वीडियो स्ट्रीमिंग बॉक्स जहां पहले 7900 रुपए की रेंज में बिक रहा था अब इस टीवी बॉक्स की कीमत 5900 रुपए हो गई है ।
# 2000 रुपए कम होने के बाद अब ये टीवी स्ट्रीमिंग बॉक्स ज्यादा अफोर्डेबल हो गया है ।
# ये दिखने में बहुत छोटा है और इंटरनेट से कनेक्ट होने पर ये डिवाइस टीवी स्क्रीन पर इंटरनेट से वीडियो स्ट्रीम कर सकता है ।
# इंटरनेट की लाइव टीवी और मूवी वेबसाइट्स जैसे नेटफ्लिक्स और HBO आदि की फिल्में , टीवी शो और बाकी वीडियोज अपने टीवी पर देखे जा सकते हैं ।
# एप्पल टीवी के जरिए स्ट्रीम किए गए कंटेंट की क्वालिटी बहुत अच्छी होती है ।
# ऑनलाइन फ्री मूवीज भी देखी जा सकेंगी ।
# एप्पल टीवी को रिमोट की जगह एक Apple ' s Remote ऐप के जरिए आईफोन या आईपैड से भी कंट्रोल किया जा सकता है ।
# इसके जरिए स्पोर्ट्स चैनल का ऑनलाइन कंटेंट भी देखा जा सकता है ।
# एप्पल टीवी HBO और ESPN जैसे चैनल का सब्सक्रिप्शन लेने की सुविधा देता है ।
# आईफोन या आईपैड में देखे जाने वाले कंटेंट को टीवी की बड़ी स्क्रीन पर देखा जा सकता है ।
# आईपैड या आईफोन में खेले जा सकने वाले गेम्स भी टीवी पर देखे और खेले जा सकते हैं ।
# इसमें पांच या छह एप्लीकेशन साइड - बाय - साइड रन कर सकते हैं ।
# यह नए तरह का डेस्कटॉप है ।
# स्क्रीन बेस पर वेंटिलेशन दी गई है , जिससे आईमॅक साउंडलेस रहता है ।
# गेमिंग का अद्भुत अनुभव है ।
# प्लैक्स या एक्सबीएमसी की मदद से इस पर 4K फिल्म का मज़ा उठाया जा सकता है ।
# टीवी स्ट्रीम करना भी आसान है ।
# ग्रिड सपोर्टेड गेम्स में बैटमैन अरखम , ऑरिजन्स और स्ट्रीट फाइटर एक्स टेक्कन उपलब्ध हैं ।
# इसका कारण हाई - क्वालिटी फिनिश है ।
# यही इसका सबसे महत्वपूर्ण फीचर भी है ।
# स्क्रीन क्वालिटी जबरदस्त है ।
# डांसिंग लाइट से डिस्ट्रैक्ट हो रहे हैं तो स्टेटिक पर शिफ्ट कर सकते हैं ।
# कुछ क्लिक से इसे पूरी तरह से बंद भी कर सकते हैं ।
# इससे पहले कि आपका ध्यान स्क्रीन की तरफ जाए , 29.6 किलो वजन वाले इस 4K टीवी का स्टैंड ध्यान अपनी तरफ खींचेगा ।
# इसमें जेस्चर सेंसिंग मैजिक रिमोट और आईपीएस एलईडी पैनल है ।
# एलईडी पैनल के जरिए इंकी ब्लैक को माइक्रो डिमिंग दे सकते हैं ।
# यानी इस पर आपको क्रिस्टल क्वालिटी मिलेगी ।
# इसके साथ , कंपनी ने इसमें Digital Noise Reduction DNR तकनीक का इस्तेमाल किया है ।
# कंपनी ने इस LED टीवी के डिस्प्ले पर खास काम किया है ।
# इसके चलते पिक्चर क्वालिटी पूरी तरह क्लियर मिलती है ।
# यानी डिस्प्ले क्वालिटी को देखते हुए इसकी कीमत बेहतर कही जा सकती है ।
# यानी 178 डिग्री एंगल से भी पिक्चर साफ नजर आएगी ।
# ये टीवी 4X ग्राफिक्स इंजन को सपोर्ट करती है ।
# साथ ही , वाई - फाई IEEE802.11N , नेटवर्क इथरनेट पोर्ट , पिक्सल मैपिंग और डिजिटल मीडिया प्लेयर बिल्ड - इन है ।

# %%
content_list = content. split("|")
print(content_list)
# Out:
# ["\ufeffअब नए फीचर से इस तरह की गलतियां नहीं होंगी और अकाउंट को हैक करना बेहद मुश्किल हो जाएगा ।\nकंपनी के मुताबिक , एंड्रॉयड के लिए आए पेरिस्कोप में सभी कोर फीचर्स हैं जो यूजर्स द्वारा पसंद किये गए हैं ।\nपेरिस्कोप एप यूजर्स भी अडिशनल पुश नोटिफिकेशन सेटिंग्स अपने हिसाब से सेट कर सकते हैं जैसे फर्स्ट टाइम ब्रॉडकास्ट नोटिफिकेशन्स और शेयर नोटिफिकेशन्स ।\nपेरिस्कोप एप में रिज्यूम नोटिफिकेशन फीचर दिया गया है जो बहुत ही खास है ।\nइस फीचर के तहत यूजर ब्रॉडकास्ट के जरिए देखे जाने वाले वीडियो रूकने पर फिर वहीं से देख सकते हैं जहां वो रूका था ।\nइस फीचर के तहत ब्रॉडकास्टर का टाइम और मोबाइल डेटा दोनों की बचत होती है ।\nआपके स्मार्टफोन में ज्यादातर एप ऎसे ही हैं जिनसे आपको अपनी जेब का पैसा खर्च कर ही कुछ काम लिया जा सकता है , लेकिन एक ऎसी एप भी है जिसमें आपको ना केवल फ्री में रिचार्ज मिल सकता है बल्कि डिस्काउंट कूपन भी प्राप्त किए जा सकते हैं ।\nस्लिक इंटरफेस है ।\nमैसेंजर अब ब्लैकबेरी स्मार्टफोन तक ही सीमित नहीं है ।\n3जी पर मैसेज डिलीवरी व्हाट्सप्प और आर्इमैसेज की तुलना में बहुत तेज है ।\nव्हाट्सप्प जैसा फीचर है ।\nयह शायद सबसे अच्छी बात है जो उन सभी यूजर्स के साथ हो सकती है जो प्लेटफॉर्म बदलना चाहते हैं लेकिन बीबीएम फ्रेंड्सलिस्ट उन्हें ऐसा करने से रोकती है ।\nचूंकि इसका गोइंग अच्छा था , अत : मैंने एप्प्ल एप्प स्टोर से बीबीएम को डाउनलोड कर लिया ।\nहालांकि इसके अधिकतर भाग सही स्टैंडर्ड रूप में दिखते हैं , फिर भी पूरे एप्प में साइड स्वाइप्स , एक्सेस और कार्यशैली का एक अन्य स्वरूप बढ़ा देते हैं ।\nस्क्रीन के नीचे दिया गया टैब आपको चैट्स , कॉन्टैक्ट्स और ग्रुप्स के बीच नेविगेट करने की सुविधा देता है ।\nआपकी रूचि बनाये रखने के लिए , इस एप्प में काले , आसमानी , नीले और सफेद रंग के मिश्रण से युक्त पर्याप्त विजुअल एलीमेंट्स उपलब्ध हैं ।\nइसके टेक्स्ट आधारित चैट का अनुभव ठीक वैसा ही होगा जैसा कि आप आशा करते है , चैट शुरू करने का वही तरीका और हर कॉन्टैक्ट के लिए इनडिविजुअल चैट विंडो ।\nअपने प्रतिस्पर्धियों के मुकाबले ज्यादा चैनल देता है ।\nअच्छी स्ट्रीमिंग क्वालिटी है ।\nमैसिव वीडियो लाइब्रेरी है ।\nऐसी सर्विस शुरू करने वाला , यह तीसरा डायरेक्ट - टू-होम टेलिविजन सर्विस प्रोवाइडर है , और यह प्रयास बहुत ही प्रभावशाली है ।\nइसकी स्ट्रीमिंग की क्वालिटी बहुत हद तक आपके इंटरनेट कनेक्शन पर निर्भर करता है , और हर चीज सुव्यस्थित होने के कारण , टीवी चैनल बिल्कुल सही ढंग से देखे जा सकते हैं ।\nएयरटेल एप्प पर 150 चैनल देते हैं जो इसके किसी भी प्रतिस्पर्धी के मुकाबले अधिक है ।\nलाल और सफेद का कलर थीम कम्बिनेशन एयरटेल का बहुत ही सुंदर ट्रेडमार्क है ।\nवीडियो को फ्री दिखाता है ।\nमौजूदा डिजाइन निस्संदेह उपयोग और प्रेरणा से अधिक है ।\nहल्का चमकीला ग्राफिक्स अच्छा काम करेगा , जैसे कि टाटा स्कार्इ ने एवरीह्वेयर टीवी सर्विस को पैकेज किया ।\nलाइव टीवी इस एप्प के इस्तेमाल करने और उसके लिए भुगतान करने के पूरे काम का मेन प्वॉइंट है , और यह बताते हुए मुझे बहुत खुशी हो रही है कि इसका अनुभव बहुत ही अच्छा है ।\nआपको बस एक अच्छी स्पीड पर एक वार्इफार्इ या 3जी कनेक्शन की जरूरत होती है और स्ट्रीमिंग क्वालिटी भी अच्छी होती है ।\nडिटेक्टेड बैंडविथ के अनुसार , क्वालिटी को ऑटोमैटिकली मैनेज किया जाता है ।\nकिसी स्मार्टफोन या टैबलेट के मामले में , यह स्ट्रीमिंग के लिए जरूरत से ज्यादा की क्वालिटी है ।\n8 एमबीपीएस वार्इफार्इ कनेक्शन पर स्ट्रीमिंग बहुत सही होता है ।\nटाटा स्कार्इ के एवरीह्वेयर और डिश टीवी के डिश ऑन लाइन सर्विस के मुकाबले , यह बहुत अधिक है ।\nएयरटेल पॉकेट टीवी एप्प पर ऑन डिमांड सर्विस अलग अलग तरह के मूवीज की लाइब्रेरी देती है और वह बिगफ्लिक्स द्वारा पावर्ड होती है ।\nऔर इसका सबसे अच्छा भाग यह है कि मूवीज की पूरी लाइब्रेरी को बिना किसी अतिरिक्त चार्ज के स्ट्रीम किया जा सकता है ।\n60 रूपये प्रति माह में लाइव टीवी स्ट्रीमिंग और ऑन - डिमांड सेक्शन में उपलब्ध एक मैसिव मूवी लाइब्रेरी , यह बुरा सौदा नहीं है ।\nबिल्कुल र्इमानदारी से , टीवी देखने के लिए आपके स्मार्टफोन को एक वैकल्पिक स्क्रीन बनाकर एयरटेल पॉकेट टीवी , ढेर सारी फ्लेक्सिबिलिटी और सुविधा देता है ।\n' साइन ईजी एप ' आपके फोन या टैबलेट पर अपने डिजिटल डॉक्यूमेंट्स को डिजिटली साइन कर सकने की आजादी देता है ।\nइस एप की मदद से आप अपने हस्ताक्षर को रजिस्टर कर सकते हैं ।\nइसके बाद आईफोन 5एस पर फिंगप्रिंट सेंसर का उपयोग कर इसे डॉक्यूमेंट पर हस्तांतरित किया जा सकता है ।\n' एंटर साइन ईजी एप ' के साथ आईफोन 5एस के उपभोक्ताओं की  ...

# %%
from inltk.inltk import tokenize

tokenize(content ,'hi')
# Out:
# ['▁अब',
#  '▁नए',
#  '▁फीचर',
#  '▁से',
#  '▁इस',
#  '▁तरह',
#  '▁की',
#  '▁गलत',
#  'ियां',
#  '▁नहीं',
#  '▁होंगी',
#  '▁और',
#  '▁अकाउंट',
#  '▁को',
#  '▁है',
#  'क',
#  '▁करना',
#  '▁बेह',
#  'द',
#  '▁मुश्किल',
#  '▁हो',
#  '▁जाएगा',
#  '▁',
#  '।',
#  '▁कंपनी',
#  '▁के',
#  '▁मुताबिक',
#  '▁',
#  ',',
#  '▁एंड्रॉयड',
#  '▁के',
#  '▁लिए',
#  '▁आए',
#  '▁पेरि',
#  'स्कोप',
#  '▁में',
#  '▁सभी',
#  '▁कोर',
#  '▁फीचर',
#  '्स',
#  '▁हैं',
#  '▁जो',
#  '▁यूजर',
#  '्स',
#  '▁द्वारा',
#  '▁पसंद',
#  '▁किये',
#  '▁गए',
#  '▁हैं',
#  '▁',
#  '।',
#  '▁पेरि',
#  'स्कोप',
#  '▁एप',
#  '▁यूजर',
#  '्स',
#  '▁भी',
#  '▁अ',
#  'डि',
#  'शन',
#  'ल',
#  '▁पुश',
#  '▁नोट',
#  'िफिकेशन',
#  '▁सेटिंग',
#  '्स',
#  '▁अपने',
#  '▁हिसाब',
#  '▁से',
#  '▁सेट',
#  '▁कर',
#  '▁सकते',
#  '▁हैं',
#  '▁जैसे',
#  '▁फर्स्ट',
#  '▁टाइम',
#  '▁ब्रॉड',
#  'कास्ट',
#  '▁नोट',
#  'िफिकेशन',
#  '्स',
#  '▁और',
#  '▁शेयर',
#  '▁नोट',
#  'िफिकेशन',
#  '्स',
#  '▁',
#  '।',
#  '▁पेरि',
#  'स्कोप',
#  '▁एप',
#  '▁में',
#  '▁रिज',
#  '्यू',
#  'म',
#  '▁नोट',
#  'िफिकेशन',
#  '▁फीचर',
#  '▁दिया',
#  '▁गया',
#  '▁है',
#  '▁जो',
#  '▁बहुत',
#  '▁ही',
#  '▁खास',
#  '▁है',
#  '▁',
#  '।',
#  '▁इस',
#  '▁फीचर',
#  '▁के',
#  '▁तहत',
#  '▁यूजर',
#  '▁ब्रॉड',
#  'कास्ट',
#  '▁के',
#  '▁जरिए',
#  '▁देखे',
#  '▁जाने',
#  '▁वाले',
#  '▁वीडियो',
#  '▁रूक',
#  'ने',
#  '▁पर',
#  '▁फिर',
#  '▁वहीं',
#  '▁से',
#  '▁देख',
#  '▁सकते',
#  '▁हैं',
#  '▁जहां',
#  '▁वो',
#  '▁रूक',
#  'ा',
#  '▁था',
#  '▁',
#  '।',
#  '▁इस',
#  '▁फीचर',
#  '▁के',
#  '▁तहत',
#  '▁ब्रॉड',
#  'का',
#  'स्टर',
#  '▁का',
#  '▁टाइम',
#  '▁और',
#  '▁मोबाइल',
#  '▁डेटा',
#  '▁दोनों',
#  '▁की',
#  '▁बचत',
#  '▁होती',
#  '▁है',
#  '▁',
#  '।',
#  '▁आपके',
#  '▁स्मार्टफोन',
#  '▁में',
#  '▁ज्यादातर',
#  '▁एप',
#  '▁',
#  'ऎ',
#  'से',
#  '▁ही',
#  '▁हैं',
#  '▁जिनसे',
#  '▁आपको',
#  '▁अपनी',
#  '▁जेब',
#  '▁का',
#  '▁पैसा',
#  '▁खर्च',
#  '▁कर',
#  '▁ही',
#  '▁कुछ',
#  '▁काम',
#  '▁लिया',
#  '▁जा',
#  '▁सकता',
#  '▁है',
#  '▁',
#  ',',
#  '▁लेकिन',
#  '▁एक',
#  '▁',
#  'ऎ',
#  'सी',
#  '▁एप',
#  '▁भी',
#  '▁है',
#  '▁जिसमें',
#  '▁आपको',
#  '▁ना',
#  '▁केवल',
#  '▁फ्री',
#  '▁में',
#  '▁रि',
#  'चार्ज',
#  '▁मिल',
#  '▁सकता',
#  '▁है',
#  '▁बल्कि',
#  '▁डिस्क',
#  'ाउंट',
#  '▁कूप',
#  'न',
#  '▁भी',
#  '▁प्राप्त',
#  '▁किए',
#  '▁जा',
#  '▁सकते',
#  '▁हैं',
#  '▁',
#  '।',
#  '▁स्',
#  'लिक',
#  '▁इंटरफेस',
#  '▁है',
#  '▁',
#  '।',
#  '▁मैसेंजर',
#  '▁अब',
#  '▁ब्लैक',
#  'बेरी',
#  '▁स्मार्टफोन',
#  '▁तक',
#  '▁ही',
#  '▁सीमित',
#  '▁नहीं',
#  '▁है',
#  '▁',
#  '।',
#  '▁3',
#  'जी',
#  '▁पर',
#  '▁मैस',
#  'ेज',
#  '▁डिलीवर',
#  'ी',
#  '▁',
#  'व्हा',
#  'ट्स',
#  'प्प',
#  '▁और',
#  '▁आर्',
#  'इम',
#  'ैस',
#  'ेज',
#  '▁की',
#  '▁तुलना',
#  '▁में',
#  '▁बहुत',
#  '▁तेज',
#  '▁है',
#  '▁',
#  '।',
#  '▁',
#  'व्हा',
#  'ट्स',
#  'प्प',
#  '▁जैसा',
#  '▁फीचर',
#  '▁है',
#  '▁',
#  '।',
#  '▁यह',
#  '▁शायद',
#  '▁सबसे',
#  '▁अच्छी',
#  '▁बात',
#  '▁है',
#  '▁जो',
#  '▁उन',
#  '▁सभी',
#  '▁यूजर',
#  '्स',
#  '▁के',
#  '▁साथ',
#  '▁हो',
#  '▁सकती',
#  '▁है',
#  '▁जो',
#  '▁प्लेटफॉर्म',
#  '▁बदलना',
#  '▁चाहते',
#  '▁हैं',
#  '▁लेकिन',
#  '▁बीबी',
#  'एम',
#  '▁फ्रेंड्स',
#  'लिस्ट',
#  '▁उन्हें',
#  '▁ऐसा',
#  '▁करने',
#  '▁से',
#  '▁रोकती',
#  '▁है',
#  '▁',
#  '।',
#  '▁चूंकि',
#  '▁इसका',
#  '▁गो',
#  'इंग',
#  '▁अच्छा',
#  '▁था',
#  '▁',
#  ',',
#  '▁अत',
#  '▁:',
#  '▁मैंने',
#  '▁एप्',
#  'प्ल',
#  '▁ए',
#  'प्प',
#  '▁स्टोर',
#  '▁से',
#  '▁बीबी',
#  'एम',
#  '▁को',
#  '▁डाउनलोड',
#  '▁कर',
#  '▁लिया',
#  '▁',
#  '।',
#  '▁हालांकि',
#  '▁इसके',
#  '▁अधिकतर',
#  '▁भाग',
#  '▁सही',
#  '▁स्टैंडर्ड',
#  '▁रूप',
#  '▁में',
#  '▁दिखते',
#  '▁हैं',
#  '▁',
#  ',',
#  '▁फिर',
#  '▁भी',
#  '▁पूरे',
#  '▁ए',
#  'प्प',
#  '▁में',
#  '▁साइड',
#  '▁स्वा',
#  'इ',
#  'प्स',
#  '▁',
#  ',',
#  '▁एक्सेस',
#  '▁और',
#  '▁कार्य',
#  'शैली',
#  '▁का',
#  '▁एक',
#  '▁अन्य',
#  '▁स्वरूप',
#  '▁बढ़ा',
#  '▁देते',
#  '▁हैं',
#  '▁',
#  '।',
#  '▁स्क्रीन',
#  '▁के',
#  '▁नीचे',
#  '▁दिया',
#  '▁गया',
#  '▁टै',
#  'ब',
#  '▁आपको',
#  '▁चैट',
#  '्स',
#  '▁',
#  ',',
#  '▁कॉन्',
#  'टैक',
#  '्ट्स',
#  '▁और',
#  '▁ग्रुप',
#  '्स',
#  '▁के',
#  '▁बीच',
#  '▁ने',
#  'वि',
#  'गेट',
#  '▁करने',
#  '▁की',
#  '▁सुविधा',
#  '▁देता',
#  '▁है',
#  '▁',
#  '।',
#  '▁आप',
#  'की',
#  '▁रूचि',
#  '▁बनाये',
#  '▁रखने',
#  '▁के',
#  '▁लिए',
#  '▁',
#  ',',
#  '▁इस',
#  '▁ए',
#  'प्प',
#  '▁में',
#  '▁काले',
#  '▁',
#  ',',
#  '▁आसमान',
#  'ी',
#  '▁',
#  ',',
#  '▁नीले',
#  '▁और',
#  '▁सफेद',
#  '▁रंग',
#  '▁के',
#  '▁मिश्रण',
#  '▁से',
#  '▁युक्त',
#  '▁पर्याप्त',
#  '▁विजुअल',
#  '▁एली',
#  'मेंट',
#  '्स',
#  '▁उपलब्ध',
#  '▁हैं',
#  '▁',
#  '।',
#  '▁इसके',
#  '▁टेक्स्ट',
#  '▁आधारित',
#  '▁चैट',
#  '▁का',
#  '▁अनुभव',
#  '▁ठीक',
#  '▁वैसा',
#  '▁ही',
#  '▁होगा',
#  '▁जैसा',
#  '▁कि',
#  '▁आप',
#  '▁आशा',
#  '▁करते',
#  '▁है',
#  '▁',
#  ',',
#  '▁चैट',
#  '▁शुरू',
#  '▁करने',
#  '▁का',
#  '▁वही',
#  '▁तरीका',
#  '▁और',
#  '▁हर',
#  '▁कॉन्',
#  'ट',
#  'ैक्ट',
#  '▁के',
#  '▁लिए',
#  '▁इन',
#  'डि',
#  'वि',
#  'ज',
#  'ुअल',
#  '▁चैट',
#  '▁विंडो',
#  '▁',
#  '।',
#  '▁अपने',
#  '▁प्रति',
#  'स्प',
#  'र्ध',
#  'ियों',
#  '▁के',
#  '▁मुकाबले',
#  '▁ज्यादा',
#  '▁चैनल',
#  '▁देता',
#  '▁है',
#  '▁',
#  '।',
#  '▁अच्छी',
#  '▁स्ट्रीमिंग',
#  '▁क्वालिटी',
#  '▁है',
#  '▁',
#  '।',
#  '▁मै',
#  'सिव',
#  '▁वीडियो',
#  '▁लाइब्रेरी',
#  '▁है',
#  '▁',
#  '।',
#  '▁ऐसी',
#  '▁सर्विस',
#  '▁शुरू',
#  '▁करने',
#  '▁वाला',
#  '▁',
#  ',',
#  '▁यह',
#  '▁तीसरा',
#  '▁डायरेक्ट',
#  '▁-',
#  '▁टू',
#  '-',
#  'होम',
#  '▁टेलिविज',
#  'न',
#  '▁सर्विस',
#  '▁प्रो',
#  'वाइड',
#  'र',
#  '▁है',
#  '▁',
#  ',',
#  '▁और',
#  '▁यह',
#  '▁प्रयास',
#  '▁बहुत',
#  '▁ही',
#  '▁प्रभावशाली',
#  '▁है',
#  '▁',
#  '।',
#  '▁इसकी',
#  '▁स्ट्रीमिंग',
#  '▁की',
#  '▁क्वालिटी',
#  '▁बहुत',
#  '▁हद',
#  '▁तक',
#  '▁आपके',
#  '▁इंटरनेट',
#  '▁कनेक्शन',
#  '▁पर',
#  '▁निर्भर',
#  '▁करता',
#  '▁है',
#  '▁',
#  ',',
#  '▁और',
#  '▁हर',
#  '▁चीज',
#  '▁सु',
#  'व्य',
#  'स्थित',
#  '▁होने',
#  '▁के',
#  '▁कारण',
#  '▁',
#  ',',
#  '▁टीवी',
#  '▁चैनल',
#  '▁',
#  'बिल्कुल',
#  '▁सही',
#  '▁ढंग',
#  '▁से',
#  '▁देखे',
#  '▁जा',
#  '▁सकते',
#  '▁हैं',
#  '▁',
#  '।',
#  '▁एयरटेल',
#  '▁ए',
#  'प्प',
#  '▁पर',
#  '▁150',
#  '▁चैनल',
#  '▁देते',
#  '▁हैं',
#  '▁जो',
#  '▁इसके',
#  '▁किसी',
#  '▁भी',
#  '▁प्रतिस्पर्धी',
#  '▁के',
#  '▁मुकाबले',
#  '▁अधिक',
#  '▁है',
#  '▁',
#  '।',
#  '▁लाल',
#  '▁और',
#  '▁सफेद',
#  '▁का',
#  '▁कलर',
#  '▁थीम',
#  '▁कम',
#  '्ब',
#  'िनेशन',
#  '▁एयरटेल',
#  '▁का',
#  '▁बहुत',
#  '▁ही',
#  '▁सुंदर',
#  '▁ट्रेडमार्क',
#  '▁है',
#  '▁',
#  '।',
#  '▁वीडियो',
#  '▁को',
#  '▁फ्री',
#  '▁दिखाता',
#  '▁है',
#  '▁',
#  '।',
#  '▁मौजूदा',
#  '▁डिजाइन',
#  '▁निस्संदेह',
#  '▁उपयोग',
#  '▁और',
#  '▁प्रेरणा',
#  '▁से',
#  '▁अधिक',
#  '▁है',
#  '▁',
#  '।',
#  '▁हल्का',
#  '▁चमकीला',
#  '▁ग्राफिक्स',
#  '▁अच्छा',
#  '▁काम',
#  '▁करेगा',
#  '▁',
#  ',',
#  '▁जैसे',
#  '▁कि',
#  '▁टाटा',
#  '▁स्कार्',
#  'इ',
#  '▁ने',
#  '▁एवर',
#  'ी',
#  'ह्',
#  'वेयर',
#  '▁टीवी',
#  '▁सर्विस',
#  '▁को',
#  '▁पैकेज',
#  '▁किया',
#  '▁',
#  '।',
#  '▁लाइव',
#  '▁टीवी',
#  '▁इस',
#  '▁ए',
#  'प्प',
#  '▁के',
#  '▁इस्तेमाल',
#  '▁करने',
#  '▁और',
#  '▁उसके',
#  '▁लिए',
#  '▁भुगतान',
#  '▁करने',
#  '▁के',
#  '▁पूरे',
#  '▁काम',
#  '▁का',
#  '▁मेन',
#  '▁प',
#  '्वॉइ',
#  'ंट',
#  '▁है',
#  '▁',
#  ',',
#  '▁और',
#  '▁यह',
#  '▁बताते',
#  '▁हुए',
#  '▁मुझे',
#  '▁बहुत',
#  '▁खुशी',
#  '▁हो',
#  '▁रही',
#  '▁है',
#  '▁कि',
#  '▁इसका',
#  '▁अनुभव',
#  '▁बहुत',
#  '▁ही',
#  '▁अच्छा',
#  '▁है',
#  '▁',
#  '।',
#  '▁आपको',
#  '▁बस',
#  '▁एक',
#  '▁अच्छी',
#  '▁स्पीड',
#  '▁पर',
#  '▁एक',
#  '▁वार्',
#  'इ',
#  'फा',
#  'र्',
#  'इ',
#  '▁या',
#  '▁3',
#  'जी',
#  '▁कनेक्शन',
#  '▁की',
#  '▁जरूरत',
#  '▁होती',
#  '▁है',
#  '▁और',
#  '▁स्ट्रीमिंग',
#  '▁क्वालिटी',
#  '▁भी',
#  '▁अच्छी',
#  '▁होती',
#  '▁है',
#  '▁',
#  '।',
#  '▁डि',
#  'टेक',
#  '्टेड',
#  '▁बैंड',
#  'वि',
#  'थ',
#  '▁के',
#  '▁अनुसार',
#  '▁',
#  ',',
#  '▁क्वालिटी',
#  '▁को',
#  '▁ऑटो',
#  'मैटिक',
#  'ली',
#  '▁मैने',
#  'ज',
#  '▁किया',
#  '▁जाता',
#  '▁है',
#  '▁',
#  '।',
#  '▁किसी',
#  '▁स्मार्टफोन',
#  '▁या',
#  '▁टैबलेट',
#  '▁के',
#  '▁मामले',
#  '▁में',
#  '▁',
#  ',',
#  '▁यह',
#  '▁स्ट्रीमिंग',
#  '▁के',
#  '▁लिए',
#  '▁जरूरत',
#  '▁से',
#  '▁ज्यादा',
#  '▁की',
#  '▁क्वालिटी',
#  '▁है',
#  '▁',
#  '।',
#  '▁8',
#  '▁एमबी',
#  'पीएस',
#  '▁वार्',
#  'इ',
#  'फा',
#  'र्',
#  'इ',
#  '▁कनेक्शन',
#  '▁पर',
#  '▁स्ट्रीमिंग',
#  '▁बहुत',
#  '▁सही',
#  '▁होता',
#  '▁है',
#  '▁',
#  '।',
#  '▁टाटा',
#  '▁स्कार्',
#  'इ',
#  '▁के',
#  '▁एवर',
#  'ी',
#  'ह्',
#  'वेयर',
#  '▁और',
#  '▁डि',
#  'श',
#  '▁टीवी',
#  '▁के',
#  '▁डि',
#  'श',
#  '▁ऑन',
#  '▁लाइन',
#  '▁सर्विस',
#  '▁के',
#  '▁मुकाबले',
#  '▁',
#  ',',
#  '▁यह',
#  '▁बहुत',
#  '▁अधिक',
#  '▁है',
#  '▁',
#  '।',
#  '▁एयरटेल',
#  '▁पॉकेट',
#  '▁टीवी',
#  '▁ए',
#  'प्प',
#  '▁पर',
#  '▁ऑन',
#  '▁डि',
#  'मांड',
#  '▁सर्विस',
#  '▁अलग',
#  '▁अलग',
#  '▁तरह',
#  '▁के',
#  '▁मूवी',
#  'ज',
#  '▁की',
#  '▁लाइब्रेरी',
#  '▁देती',
#  '▁है',
#  '▁और',
#  '▁वह',
#  '▁बिग',
#  'फ्ल',
#  'िक्स',
#  '▁द्वारा',
#  '▁पावर',
#  '्ड',
#  '▁होती',
#  '▁है',
#  '▁',
#  '।',
#  '▁और',
#  '▁इसका',
#  '▁सबसे',
#  '▁अच्छा',
#  '▁भाग',
#  '▁यह',
#  '▁है',
#  '▁कि',
#  '▁मूवी',
#  'ज',
#  '▁की',
#  '▁पूरी',
#  '▁लाइब्रेरी',
#  '▁को',
#  '▁बिना',
#  '▁किसी',
#  '▁अतिरिक्त',
#  '▁चार्ज',
#  '▁के',
#  '▁स्ट्रीम',
#  '▁किया',
#  '▁जा',
#  '▁सकता',
#  '▁है',
#  '▁',
#  '।',
#  '▁60',
#  '▁रूपये',
#  '▁प्रति',
#  '▁माह',
#  '▁में',
#  '▁लाइव',
#  '▁टीवी',
#  '▁स्ट्रीमिंग',
#  '▁और',
#  '▁ऑन',
#  '▁-',
#  '▁डि',
#  'मांड',
#  '▁से',
#  'क्शन',
#  '▁में',
#  '▁उपलब्ध',
#  '▁एक',
#  '▁मै',
#  'सिव',
#  '▁मूवी',
#  '▁लाइब्रेरी',
#  '▁',
#  ',',
#  '▁यह',
#  '▁बुरा',
#  '▁सौदा',
#  '▁नहीं',
#  '▁है',
#  '▁',
#  '।',
#  '▁',
#  'बिल्कुल',
#  '▁',
#  'र्',
#  'इ',
#  'मान',
#  'दारी',
#  '▁से',
#  '▁',
#  ',',
#  '▁टीवी',
#  '▁देखने',
#  '▁के',
#  '▁लिए',
#  '▁आपके',
#  '▁स्मार्टफोन',
#  '▁को',
#  '▁एक',
#  '▁वैकल्पिक',
#  '▁स्क्रीन',
#  '▁बनाकर',
#  '▁एयरटेल',
#  '▁पॉकेट',
#  '▁टीवी',
#  '▁',
#  ',',
#  '▁ढेर',
#  '▁सारी',
#  '▁',
#  'फ्लेक्स',
#  'िब',
#  'िलिटी',
#  '▁और',
#  '▁सुविधा',
#  '▁देता',
#  '▁है',
#  '▁',
#  '।',
#  "▁'",
#  '▁साइन',
#  '▁ई',
#  'जी',
#  '▁एप',
#  "▁'",
#  '▁आपके',
#  '▁फोन',
#  '▁या',
#  '▁टैबलेट',
#  '▁पर',
#  '▁अपने',
#  '▁डिजिटल',
#  '▁डॉ',
#  'क्यू',
#  'मेंट',
#  '्स',
#  '▁को',
#  '▁डिजिटल',
#  'ी',
#  '▁साइन',
#  '▁कर',
#  '▁सकने',
#  '▁की',
#  '▁आजादी',
#  '▁देता',
#  '▁है',
#  '▁',
#  '।',
#  '▁इस',
#  '▁एप',
#  '▁की',
#  '▁मदद',
#  '▁से',
#  '▁आप',
#  '▁अपने',
#  '▁हस्ताक्षर',
#  '▁को',
#  '▁रजिस्टर',
#  '▁कर',
#  '▁सकते',
#  '▁हैं',
#  '▁',
#  '।',
#  '▁इसके',
#  '▁बाद',
#  '▁आई',
#  'फोन',
#  '▁5',
#  'एस',
#  '▁पर',
#  '▁फ',
#  'िंग',
#  'प्रिंट',
#  '▁सेंसर',
#  '▁का',
#  '▁उपयोग',
#  '▁कर',
#  '▁इसे',
#  '▁डॉ',
#  'क्यू',
#  'मेंट',
#  '▁पर',
#  '▁हस्तांतरित',
#  '▁किया',
#  '▁जा',
#  ...]

# %%
from inltk.inltk import get_embedding_vectors
vectors = get_embedding_vectors('भारत', 'hi')
# Out:
# /usr/local/lib/python3.6/dist-packages/torch/serialization.py:658: SourceChangeWarning: source code of class 'torch.nn.modules.loss.CrossEntropyLoss' has changed. you can retrieve the original source code by accessing the object's source attribute or set `torch.nn.Module.dump_patches = True` and use the patch tool to revert the changes.
#   warnings.warn(msg, SourceChangeWarning)
# /usr/local/lib/python3.6/dist-packages/torch/serialization.py:658: SourceChangeWarning: source code of class 'fastai.text.models.awd_lstm.AWD_LSTM' has changed. you can retrieve the original source code by accessing the object's source attribute or set `torch.nn.Module.dump_patches = True` and use the patch tool to revert the changes.
#   warnings.warn(msg, SourceChangeWarning)
# /usr/local/lib/python3.6/dist-packages/torch/serialization.py:658: SourceChangeWarning: source code of class 'torch.nn.modules.sparse.Embedding' has changed. you can retrieve the original source code by accessing the object's source attribute or set `torch.nn.Module.dump_patches = True` and use the patch tool to revert the changes.
#   warnings.warn(msg, SourceChangeWarning)
# /usr/local/lib/python3.6/dist-packages/torch/serialization.py:658: SourceChangeWarning: source code of class 'fastai.text.models.awd_lstm.EmbeddingDropout' has changed. you can retrieve the original source code by accessing the object's source attribute or set `torch.nn.Module.dump_patches = True` and use the patch tool to revert the changes.
#   warnings.warn(msg, SourceChangeWarning)
# /usr/local/lib/python3.6/dist-packages/torch/serialization.py:658: SourceChangeWarning: source code of class 'torch.nn.modules.container.ModuleList' has changed. you can retrieve the original source code by accessing the object's source attribute or set `torch.nn.Module.dump_patches = True` and use the patch tool to revert the changes.
#   warnings.warn(msg, SourceChangeWarning)
# /usr/local/lib/python3.6/dist-packages/torch/serialization.py:658: SourceChangeWarning: source code of class 'fastai.text.models.awd_lstm.WeightDropout' has changed. you can retrieve the original source code by accessing the object's source attribute or set `torch.nn.Module.dump_patches = True` and use the patch tool to revert the changes.
#   warnings.warn(msg, SourceChangeWarning)
# /usr/local/lib/python3.6/dist-packages/torch/serialization.py:658: SourceChangeWarning: source code of class 'torch.nn.modules.rnn.LSTM' has changed. you can retrieve the original source code by accessing the object's source attribute or set `torch.nn.Module.dump_patches = True` and use the patch tool to revert the changes.
#   warnings.warn(msg, SourceChangeWarning)
# /usr/local/lib/python3.6/dist-packages/torch/serialization.py:658: SourceChangeWarning: source code of class 'fastai.text.models.awd_lstm.RNNDropout' has changed. you can retrieve the original source code by accessing the object's source attribute or set `torch.nn.Module.dump_patches = True` and use the patch tool to revert the changes.
#   warnings.warn(msg, SourceChangeWarning)
# /usr/local/lib/python3.6/dist-packages/torch/serialization.py:658: SourceChangeWarning: source code of class 'fastai.text.models.awd_lstm.LinearDecoder' has changed. you can retrieve the original source code by accessing the object's source attribute or set `torch.nn.Module.dump_patches = True` and use the patch tool to revert the changes.
#   warnings.warn(msg, SourceChangeWarning)
# /usr/local/lib/python3.6/dist-packages/torch/serialization.py:658: SourceChangeWarning: source code of class 'torch.nn.modules.linear.Linear' has changed. you can retrieve the original source code by accessing the object's source attribute or set `torch.nn.Module.dump_patches = True` and use the patch tool to revert the changes.
#   warnings.warn(msg, SourceChangeWarning)
# ---------------------------------------------------------------------------
# ModuleAttributeError                      Traceback (most recent call last)
# <ipython-input-11-3b09bd99aa2a> in <module>()
#       1 from inltk.inltk import get_embedding_vectors
# ----> 2 vectors = get_embedding_vectors('भारत', 'hi')
#       3 vectors = get_embedding_vectors('भारत', 'hi')
#       4 vectors[0].shape
#
# /usr/local/lib/python3.6/dist-packages/inltk/inltk.py in get_embedding_vectors(input, language_code)
#      98     defaults.device = torch.device('cpu')
#      99     path = Path(__file__).parent
# --> 100     learn = load_learner(path / 'models' / f'{language_code}')
#     101     encoder = get_model(learn.model)[0]
#     102     encoder.reset()
#
# /usr/local/lib/python3.6/dist-packages/fastai/basic_train.py in load_learner(path, file, test, **db_kwargs)
#     624     cb_state = state.pop('cb_state')
#     625     clas_func = state.pop('cls')
# --> 626     res = clas_func(data, model, **state)
#     627     res.callback_fns = state['callback_fns'] #to avoid duplicates
#     628     res.callbacks = [load_callback(c,s, res) for c,s in cb_state.items()]
#
# /usr/local/lib/python3.6/dist-packages/fastai/text/learner.py in __init__(self, data, model, split_func, clip, alpha, beta, metrics, **learn_kwargs)
#      50                                                      isinstance(data.train_ds.y, LMLabelList)))
#      51         metrics = ifnone(metrics, ([accuracy] if is_class else []))
# ---> 52         super().__init__(data, model, metrics=metrics, **learn_kwargs)
#      53         self.callbacks.append(RNNTrainer(self, alpha=alpha, beta=beta))
#      54         if clip: self.callback_fns.append(partial(GradientClipping, clip=clip))
#
# <string> in __init__(self, data, model, opt_func, loss_func, metrics, true_wd, bn_wd, wd, train_bn, path, model_dir, callback_fns, callbacks, layer_groups, add_time, silent, cb_fns_registered)
#
# /usr/local/lib/python3.6/dist-packages/fastai/basic_train.py in __post_init__(self)
#     164         "Setup path,metrics, callbacks and ensure model directory exists."
#     165         self.path = Path(ifnone(self.path, self.data.path))
# --> 166         self.model = self.model.to(self.data.device)
#     167         self.loss_func = self.loss_func or self.data.loss_func
#     168         self.metrics=listify(self.metrics)
#
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/module.py in to(self, *args, **kwargs)
#     610             return t.to(device, dtype if t.is_floating_point() else None, non_blocking)
#     611
# --> 612         return self._apply(convert)
#     613
#     614     def register_backward_hook(
#
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/module.py in _apply(self, fn)
#     357     def _apply(self, fn):
#     358         for module in self.children():
# --> 359             module._apply(fn)
#     360
#     361         def compute_should_use_set_data(tensor, tensor_applied):
#
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/module.py in _apply(self, fn)
#     357     def _apply(self, fn):
#     358         for module in self.children():
# --> 359             module._apply(fn)
#     360
#     361         def compute_should_use_set_data(tensor, tensor_applied):
#
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/module.py in _apply(self, fn)
#     357     def _apply(self, fn):
#     358         for module in self.children():
# --> 359             module._apply(fn)
#     360
#     361         def compute_should_use_set_data(tensor, tensor_applied):
#
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/module.py in _apply(self, fn)
#     357     def _apply(self, fn):
#     358         for module in self.children():
# --> 359             module._apply(fn)
#     360
#     361         def compute_should_use_set_data(tensor, tensor_applied):
#
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/rnn.py in _apply(self, fn)
#     158         # Note: be v. careful before removing this, as 3rd party device types
#     159         # likely rely on this behavior to properly .to() modules like LSTM.
# --> 160         self._flat_weights = [(lambda wn: getattr(self, wn) if hasattr(self, wn) else None)(wn) for wn in self._flat_weights_names]
#     161         # Flattens params (on CUDA)
#     162         self.flatten_parameters()
#
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/module.py in __getattr__(self, name)
#     777                 return modules[name]
#     778         raise ModuleAttributeError("'{}' object has no attribute '{}'".format(
# --> 779             type(self).__name__, name))
#     780
#     781     def __setattr__(self, name: str, value: Union[Tensor, 'Module']) -> None:
#
# ModuleAttributeError: 'LSTM' object has no attribute '_flat_weights_names'

# %%
from inltk.inltk import get_sentence_encoding
encoding = get_sentence_encoding('मुझे अपने देश से', 'hi')
encoding.shape
# Out:
# /usr/local/lib/python3.6/dist-packages/torch/serialization.py:658: SourceChangeWarning: source code of class 'torch.nn.modules.loss.CrossEntropyLoss' has changed. you can retrieve the original source code by accessing the object's source attribute or set `torch.nn.Module.dump_patches = True` and use the patch tool to revert the changes.
#   warnings.warn(msg, SourceChangeWarning)
# /usr/local/lib/python3.6/dist-packages/torch/serialization.py:658: SourceChangeWarning: source code of class 'fastai.text.models.awd_lstm.AWD_LSTM' has changed. you can retrieve the original source code by accessing the object's source attribute or set `torch.nn.Module.dump_patches = True` and use the patch tool to revert the changes.
#   warnings.warn(msg, SourceChangeWarning)
# /usr/local/lib/python3.6/dist-packages/torch/serialization.py:658: SourceChangeWarning: source code of class 'torch.nn.modules.sparse.Embedding' has changed. you can retrieve the original source code by accessing the object's source attribute or set `torch.nn.Module.dump_patches = True` and use the patch tool to revert the changes.
#   warnings.warn(msg, SourceChangeWarning)
# /usr/local/lib/python3.6/dist-packages/torch/serialization.py:658: SourceChangeWarning: source code of class 'fastai.text.models.awd_lstm.EmbeddingDropout' has changed. you can retrieve the original source code by accessing the object's source attribute or set `torch.nn.Module.dump_patches = True` and use the patch tool to revert the changes.
#   warnings.warn(msg, SourceChangeWarning)
# /usr/local/lib/python3.6/dist-packages/torch/serialization.py:658: SourceChangeWarning: source code of class 'torch.nn.modules.container.ModuleList' has changed. you can retrieve the original source code by accessing the object's source attribute or set `torch.nn.Module.dump_patches = True` and use the patch tool to revert the changes.
#   warnings.warn(msg, SourceChangeWarning)
# /usr/local/lib/python3.6/dist-packages/torch/serialization.py:658: SourceChangeWarning: source code of class 'fastai.text.models.awd_lstm.WeightDropout' has changed. you can retrieve the original source code by accessing the object's source attribute or set `torch.nn.Module.dump_patches = True` and use the patch tool to revert the changes.
#   warnings.warn(msg, SourceChangeWarning)
# /usr/local/lib/python3.6/dist-packages/torch/serialization.py:658: SourceChangeWarning: source code of class 'torch.nn.modules.rnn.LSTM' has changed. you can retrieve the original source code by accessing the object's source attribute or set `torch.nn.Module.dump_patches = True` and use the patch tool to revert the changes.
#   warnings.warn(msg, SourceChangeWarning)
# /usr/local/lib/python3.6/dist-packages/torch/serialization.py:658: SourceChangeWarning: source code of class 'fastai.text.models.awd_lstm.RNNDropout' has changed. you can retrieve the original source code by accessing the object's source attribute or set `torch.nn.Module.dump_patches = True` and use the patch tool to revert the changes.
#   warnings.warn(msg, SourceChangeWarning)
# /usr/local/lib/python3.6/dist-packages/torch/serialization.py:658: SourceChangeWarning: source code of class 'fastai.text.models.awd_lstm.LinearDecoder' has changed. you can retrieve the original source code by accessing the object's source attribute or set `torch.nn.Module.dump_patches = True` and use the patch tool to revert the changes.
#   warnings.warn(msg, SourceChangeWarning)
# /usr/local/lib/python3.6/dist-packages/torch/serialization.py:658: SourceChangeWarning: source code of class 'torch.nn.modules.linear.Linear' has changed. you can retrieve the original source code by accessing the object's source attribute or set `torch.nn.Module.dump_patches = True` and use the patch tool to revert the changes.
#   warnings.warn(msg, SourceChangeWarning)
# ---------------------------------------------------------------------------
# ModuleAttributeError                      Traceback (most recent call last)
# <ipython-input-15-181d731aefd3> in <module>()
#       1 from inltk.inltk import get_sentence_encoding
# ----> 2 encoding = get_sentence_encoding('मुझे अपने देश से', 'hi')
#       3 encoding.shape
#
# /usr/local/lib/python3.6/dist-packages/inltk/inltk.py in get_sentence_encoding(input, language_code)
#     116     defaults.device = torch.device('cpu')
#     117     path = Path(__file__).parent
# --> 118     learn = load_learner(path / 'models' / f'{language_code}')
#     119     encoder = learn.model[0]
#     120     encoder.reset()
#
# /usr/local/lib/python3.6/dist-packages/fastai/basic_train.py in load_learner(path, file, test, **db_kwargs)
#     624     cb_state = state.pop('cb_state')
#     625     clas_func = state.pop('cls')
# --> 626     res = clas_func(data, model, **state)
#     627     res.callback_fns = state['callback_fns'] #to avoid duplicates
#     628     res.callbacks = [load_callback(c,s, res) for c,s in cb_state.items()]
#
# /usr/local/lib/python3.6/dist-packages/fastai/text/learner.py in __init__(self, data, model, split_func, clip, alpha, beta, metrics, **learn_kwargs)
#      50                                                      isinstance(data.train_ds.y, LMLabelList)))
#      51         metrics = ifnone(metrics, ([accuracy] if is_class else []))
# ---> 52         super().__init__(data, model, metrics=metrics, **learn_kwargs)
#      53         self.callbacks.append(RNNTrainer(self, alpha=alpha, beta=beta))
#      54         if clip: self.callback_fns.append(partial(GradientClipping, clip=clip))
#
# <string> in __init__(self, data, model, opt_func, loss_func, metrics, true_wd, bn_wd, wd, train_bn, path, model_dir, callback_fns, callbacks, layer_groups, add_time, silent, cb_fns_registered)
#
# /usr/local/lib/python3.6/dist-packages/fastai/basic_train.py in __post_init__(self)
#     164         "Setup path,metrics, callbacks and ensure model directory exists."
#     165         self.path = Path(ifnone(self.path, self.data.path))
# --> 166         self.model = self.model.to(self.data.device)
#     167         self.loss_func = self.loss_func or self.data.loss_func
#     168         self.metrics=listify(self.metrics)
#
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/module.py in to(self, *args, **kwargs)
#     610             return t.to(device, dtype if t.is_floating_point() else None, non_blocking)
#     611
# --> 612         return self._apply(convert)
#     613
#     614     def register_backward_hook(
#
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/module.py in _apply(self, fn)
#     357     def _apply(self, fn):
#     358         for module in self.children():
# --> 359             module._apply(fn)
#     360
#     361         def compute_should_use_set_data(tensor, tensor_applied):
#
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/module.py in _apply(self, fn)
#     357     def _apply(self, fn):
#     358         for module in self.children():
# --> 359             module._apply(fn)
#     360
#     361         def compute_should_use_set_data(tensor, tensor_applied):
#
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/module.py in _apply(self, fn)
#     357     def _apply(self, fn):
#     358         for module in self.children():
# --> 359             module._apply(fn)
#     360
#     361         def compute_should_use_set_data(tensor, tensor_applied):
#
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/module.py in _apply(self, fn)
#     357     def _apply(self, fn):
#     358         for module in self.children():
# --> 359             module._apply(fn)
#     360
#     361         def compute_should_use_set_data(tensor, tensor_applied):
#
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/rnn.py in _apply(self, fn)
#     158         # Note: be v. careful before removing this, as 3rd party device types
#     159         # likely rely on this behavior to properly .to() modules like LSTM.
# --> 160         self._flat_weights = [(lambda wn: getattr(self, wn) if hasattr(self, wn) else None)(wn) for wn in self._flat_weights_names]
#     161         # Flattens params (on CUDA)
#     162         self.flatten_parameters()
#
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/module.py in __getattr__(self, name)
#     777                 return modules[name]
#     778         raise ModuleAttributeError("'{}' object has no attribute '{}'".format(
# --> 779             type(self).__name__, name))
#     780
#     781     def __setattr__(self, name: str, value: Union[Tensor, 'Module']) -> None:
#
# ModuleAttributeError: 'LSTM' object has no attribute '_flat_weights_names'

# %%
from inltk.inltk import get_sentence_similarity
get_sentence_similarity('मैं इन दोनों श्रेणियों के बीच कुछ भी सामान्य नहीं देखता।', 'मैंने कन्फेक्शनरी स्टोर्स पर सेब और संतरे की कीमतों की तुलना की', 'hi')
# Out:
# /usr/local/lib/python3.6/dist-packages/torch/serialization.py:658: SourceChangeWarning: source code of class 'torch.nn.modules.loss.CrossEntropyLoss' has changed. you can retrieve the original source code by accessing the object's source attribute or set `torch.nn.Module.dump_patches = True` and use the patch tool to revert the changes.
#   warnings.warn(msg, SourceChangeWarning)
# /usr/local/lib/python3.6/dist-packages/torch/serialization.py:658: SourceChangeWarning: source code of class 'fastai.text.models.awd_lstm.AWD_LSTM' has changed. you can retrieve the original source code by accessing the object's source attribute or set `torch.nn.Module.dump_patches = True` and use the patch tool to revert the changes.
#   warnings.warn(msg, SourceChangeWarning)
# /usr/local/lib/python3.6/dist-packages/torch/serialization.py:658: SourceChangeWarning: source code of class 'torch.nn.modules.sparse.Embedding' has changed. you can retrieve the original source code by accessing the object's source attribute or set `torch.nn.Module.dump_patches = True` and use the patch tool to revert the changes.
#   warnings.warn(msg, SourceChangeWarning)
# /usr/local/lib/python3.6/dist-packages/torch/serialization.py:658: SourceChangeWarning: source code of class 'fastai.text.models.awd_lstm.EmbeddingDropout' has changed. you can retrieve the original source code by accessing the object's source attribute or set `torch.nn.Module.dump_patches = True` and use the patch tool to revert the changes.
#   warnings.warn(msg, SourceChangeWarning)
# /usr/local/lib/python3.6/dist-packages/torch/serialization.py:658: SourceChangeWarning: source code of class 'torch.nn.modules.container.ModuleList' has changed. you can retrieve the original source code by accessing the object's source attribute or set `torch.nn.Module.dump_patches = True` and use the patch tool to revert the changes.
#   warnings.warn(msg, SourceChangeWarning)
# /usr/local/lib/python3.6/dist-packages/torch/serialization.py:658: SourceChangeWarning: source code of class 'fastai.text.models.awd_lstm.WeightDropout' has changed. you can retrieve the original source code by accessing the object's source attribute or set `torch.nn.Module.dump_patches = True` and use the patch tool to revert the changes.
#   warnings.warn(msg, SourceChangeWarning)
# /usr/local/lib/python3.6/dist-packages/torch/serialization.py:658: SourceChangeWarning: source code of class 'torch.nn.modules.rnn.LSTM' has changed. you can retrieve the original source code by accessing the object's source attribute or set `torch.nn.Module.dump_patches = True` and use the patch tool to revert the changes.
#   warnings.warn(msg, SourceChangeWarning)
# /usr/local/lib/python3.6/dist-packages/torch/serialization.py:658: SourceChangeWarning: source code of class 'fastai.text.models.awd_lstm.RNNDropout' has changed. you can retrieve the original source code by accessing the object's source attribute or set `torch.nn.Module.dump_patches = True` and use the patch tool to revert the changes.
#   warnings.warn(msg, SourceChangeWarning)
# /usr/local/lib/python3.6/dist-packages/torch/serialization.py:658: SourceChangeWarning: source code of class 'fastai.text.models.awd_lstm.LinearDecoder' has changed. you can retrieve the original source code by accessing the object's source attribute or set `torch.nn.Module.dump_patches = True` and use the patch tool to revert the changes.
#   warnings.warn(msg, SourceChangeWarning)
# /usr/local/lib/python3.6/dist-packages/torch/serialization.py:658: SourceChangeWarning: source code of class 'torch.nn.modules.linear.Linear' has changed. you can retrieve the original source code by accessing the object's source attribute or set `torch.nn.Module.dump_patches = True` and use the patch tool to revert the changes.
#   warnings.warn(msg, SourceChangeWarning)
# ---------------------------------------------------------------------------
# ModuleAttributeError                      Traceback (most recent call last)
# <ipython-input-16-6dd284dd6c20> in <module>()
#       1 from inltk.inltk import get_sentence_similarity
# ----> 2 get_sentence_similarity('मैं इन दोनों श्रेणियों के बीच कुछ भी सामान्य नहीं देखता।', 'मैंने कन्फेक्शनरी स्टोर्स पर सेब और संतरे की कीमतों की तुलना की', 'hi')
#
# /usr/local/lib/python3.6/dist-packages/inltk/inltk.py in get_sentence_similarity(sen1, sen2, language_code, cmp)
#     125 def get_sentence_similarity(sen1: str, sen2: str, language_code: str, cmp: Callable = cos_sim):
#     126     check_input_language(language_code)
# --> 127     enc1 = get_sentence_encoding(sen1, language_code)
#     128     enc2 = get_sentence_encoding(sen2, language_code)
#     129     return cmp(enc1, enc2)
#
# /usr/local/lib/python3.6/dist-packages/inltk/inltk.py in get_sentence_encoding(input, language_code)
#     116     defaults.device = torch.device('cpu')
#     117     path = Path(__file__).parent
# --> 118     learn = load_learner(path / 'models' / f'{language_code}')
#     119     encoder = learn.model[0]
#     120     encoder.reset()
#
# /usr/local/lib/python3.6/dist-packages/fastai/basic_train.py in load_learner(path, file, test, **db_kwargs)
#     624     cb_state = state.pop('cb_state')
#     625     clas_func = state.pop('cls')
# --> 626     res = clas_func(data, model, **state)
#     627     res.callback_fns = state['callback_fns'] #to avoid duplicates
#     628     res.callbacks = [load_callback(c,s, res) for c,s in cb_state.items()]
#
# /usr/local/lib/python3.6/dist-packages/fastai/text/learner.py in __init__(self, data, model, split_func, clip, alpha, beta, metrics, **learn_kwargs)
#      50                                                      isinstance(data.train_ds.y, LMLabelList)))
#      51         metrics = ifnone(metrics, ([accuracy] if is_class else []))
# ---> 52         super().__init__(data, model, metrics=metrics, **learn_kwargs)
#      53         self.callbacks.append(RNNTrainer(self, alpha=alpha, beta=beta))
#      54         if clip: self.callback_fns.append(partial(GradientClipping, clip=clip))
#
# <string> in __init__(self, data, model, opt_func, loss_func, metrics, true_wd, bn_wd, wd, train_bn, path, model_dir, callback_fns, callbacks, layer_groups, add_time, silent, cb_fns_registered)
#
# /usr/local/lib/python3.6/dist-packages/fastai/basic_train.py in __post_init__(self)
#     164         "Setup path,metrics, callbacks and ensure model directory exists."
#     165         self.path = Path(ifnone(self.path, self.data.path))
# --> 166         self.model = self.model.to(self.data.device)
#     167         self.loss_func = self.loss_func or self.data.loss_func
#     168         self.metrics=listify(self.metrics)
#
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/module.py in to(self, *args, **kwargs)
#     610             return t.to(device, dtype if t.is_floating_point() else None, non_blocking)
#     611
# --> 612         return self._apply(convert)
#     613
#     614     def register_backward_hook(
#
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/module.py in _apply(self, fn)
#     357     def _apply(self, fn):
#     358         for module in self.children():
# --> 359             module._apply(fn)
#     360
#     361         def compute_should_use_set_data(tensor, tensor_applied):
#
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/module.py in _apply(self, fn)
#     357     def _apply(self, fn):
#     358         for module in self.children():
# --> 359             module._apply(fn)
#     360
#     361         def compute_should_use_set_data(tensor, tensor_applied):
#
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/module.py in _apply(self, fn)
#     357     def _apply(self, fn):
#     358         for module in self.children():
# --> 359             module._apply(fn)
#     360
#     361         def compute_should_use_set_data(tensor, tensor_applied):
#
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/module.py in _apply(self, fn)
#     357     def _apply(self, fn):
#     358         for module in self.children():
# --> 359             module._apply(fn)
#     360
#     361         def compute_should_use_set_data(tensor, tensor_applied):
#
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/rnn.py in _apply(self, fn)
#     158         # Note: be v. careful before removing this, as 3rd party device types
#     159         # likely rely on this behavior to properly .to() modules like LSTM.
# --> 160         self._flat_weights = [(lambda wn: getattr(self, wn) if hasattr(self, wn) else None)(wn) for wn in self._flat_weights_names]
#     161         # Flattens params (on CUDA)
#     162         self.flatten_parameters()
#
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/module.py in __getattr__(self, name)
#     777                 return modules[name]
#     778         raise ModuleAttributeError("'{}' object has no attribute '{}'".format(
# --> 779             type(self).__name__, name))
#     780
#     781     def __setattr__(self, name: str, value: Union[Tensor, 'Module']) -> None:
#
# ModuleAttributeError: 'LSTM' object has no attribute '_flat_weights_names'
